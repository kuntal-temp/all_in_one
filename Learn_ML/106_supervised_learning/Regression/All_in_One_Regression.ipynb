# %% [markdown]
# # Import package

# %%
# Data Manupulation
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# impute
from sklearn.impute import SimpleImputer, KNNImputer

# ColumnTransformer
from sklearn.compose import ColumnTransformer

# preprocessing
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder, StandardScaler, MinMaxScaler, MaxAbsScaler, PolynomialFeatures

# model_selection
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV, RepeatedKFold

# metrics
from sklearn.metrics import r2_score, mean_squared_error

# linear_model
from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, LogisticRegression, SGDRegressor

# svm
from sklearn.svm import SVR, LinearSVR

# ensemble
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, StackingRegressor, VotingRegressor, ExtraTreesRegressor

# tree
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree

# cross_decomposition
from sklearn.cross_decomposition import PLSRegression

# xgboost
from xgboost import XGBRegressor, XGBRFRegressor

# lightgbm
from lightgbm import LGBMRegressor

# catboost
from catboost import CatBoostRegressor

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_csv('../../test_data/iris.csv')
df.head(2)
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa

# %%
del df['Unnamed: 0']
df.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %% [markdown]
# # x, y split

# %%
x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
x[0:2]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2]])

# %%
y[0:2]
# Out:
# array(['setosa', 'setosa'], dtype=object)

# %% [markdown]
# # LabelEncoder

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
y[0:2]
# Out:
# array([0, 0])

# %% [markdown]
# # Deal with Missing Values

# %%
imputer = KNNImputer(n_neighbors=5, missing_values=np.nan)
x[:, :] = imputer.fit_transform(x[:, :])

# %%
x[0:2]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2]])

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %% [markdown]
# # Scalling

# %%
scaler = StandardScaler()
x_train[:, :] = scaler.fit_transform(x_train[:, :])
x_test[:, :] = scaler.fit_transform(x_test[:, :])

# %%
x_train[0:2]
# Out:
# array([[-1.01827123,  1.2864604 , -1.39338902, -1.3621769 ],
#        [-0.7730102 ,  2.43545215, -1.33550342, -1.49647603]])

# %%
y_train[0:2]
# Out:
# array([0, 0])

# %%
x_test[0:2]
# Out:
# array([[ 0.25621067, -0.71903739,  0.58987181,  0.05585913],
#        [-0.21299441,  1.61629772, -1.03834577, -1.06789518]])

# %%
y_test[0:2]
# Out:
# array([1, 0])

# %% [markdown]
# # Model Quality

# %%
def print_training_score(regressor=None, X_train=None, Y_train=None):
    training_score = regressor.score(X_train, Y_train)
    print("training_score = ", training_score)

    
def print_training_cross_val_score(regressor=None, X_train=None, Y_train=None, cv=5):    
    accuracies = cross_val_score(estimator=regressor, X=X_train, y=Y_train, cv=cv)
    print("Training Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Training data Standard Deviation: {:.2f} %".format(accuracies.std()*100))

    
def print_r2_score(Y_test=None, Y_pred=None):
    r_2_score = r2_score(Y_test, Y_pred)
    print("r_2_score = ", r_2_score)

    
def print_mse_and_rmse(Y_test=None, Y_pred=None):
    mse = mean_squared_error(Y_test, Y_pred, squared=False)
    print("MSE = ", mse)
    rmse = mean_squared_error(Y_test, Y_pred, squared=True)
    print("RMSE = ", rmse)

    
def print_summary(regressor=None, x_train=None, y_train=None, y_test=None, y_pred=None):
    print_training_score(regressor=regressor, X_train=x_train, Y_train=y_train)
    print_training_cross_val_score(regressor=regressor, X_train=x_train, Y_train=y_train)

    print_r2_score(Y_test=y_test, Y_pred=y_pred)
    print_mse_and_rmse(Y_test=y_test, Y_pred=y_pred)

    np.set_printoptions(precision=2)
    print("Compare with Predict and actual\n", np.concatenate((y_test.reshape(-1,1), y_pred.reshape(-1,1)), 1)[0:10])

# %% [markdown]
# # LinearRegression

# %%
params = {
    'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': 'deprecated', 'positive': False
}
regressor = LinearRegression()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9225512936540917
# Training Accuracy: 91.13 %
# Training data Standard Deviation: 2.13 %
# r_2_score =  0.9301678301266041
# MSE =  0.22177094563474958
# RMSE =  0.049182352327731056
# Compare with Predict and actual
#  [[1.   1.31]
#  [0.   0.11]
#  [2.   2.23]
#  [1.   1.41]
#  [1.   1.36]
#  [0.   0.17]
#  [1.   1.14]
#  [2.   1.85]
#  [1.   1.43]
#  [1.   1.15]]

# %% [markdown]
# # Lasso

# %%
params = {
    'alpha': 0.3, 'copy_X': True, 'fit_intercept': True, 'max_iter': 1000, 'normalize': 'deprecated',
    'positive': False, 'precompute': False, 'random_state': None, 'selection': 'cyclic', 'tol': 0.0001,
    'warm_start': False
}
regressor = Lasso(alpha=0.3)
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.7755632913093676
# Training Accuracy: 75.51 %
# Training data Standard Deviation: 1.73 %
# r_2_score =  0.7630458465204102
# MSE =  0.4085159735132433
# RMSE =  0.1668853006154729
# Compare with Predict and actual
#  [[1.   1.17]
#  [0.   0.53]
#  [2.   1.78]
#  [1.   1.24]
#  [1.   1.24]
#  [0.   0.54]
#  [1.   1.07]
#  [2.   1.57]
#  [1.   1.24]
#  [1.   1.07]]

# %% [markdown]
# # Ridge

# %%
params = {
    'alpha': 0.1, 'copy_X': True, 'fit_intercept': True, 'max_iter': None, 'normalize': 'deprecated', 
    'positive': False, 'random_state': None, 'solver': 'auto', 'tol': 0.001
}
regressor = Ridge(alpha=0.01)
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9225483224765989
# Training Accuracy: 91.15 %
# Training data Standard Deviation: 2.13 %
# r_2_score =  0.9302304885682077
# MSE =  0.2216714288908667
# RMSE =  0.04913822238651857
# Compare with Predict and actual
#  [[1.   1.31]
#  [0.   0.11]
#  [2.   2.23]
#  [1.   1.41]
#  [1.   1.36]
#  [0.   0.17]
#  [1.   1.14]
#  [2.   1.85]
#  [1.   1.43]
#  [1.   1.15]]

# %% [markdown]
# # ElasticNet

# %%
params = {
    'alpha': 0.2, 'copy_X': True, 'fit_intercept': True, 'l1_ratio': 0.5, 'max_iter': 1000, 
    'normalize': 'deprecated', 'positive': False, 'precompute': False, 'random_state': None, 
    'selection': 'cyclic', 'tol': 0.0001, 'warm_start': False
}
regressor = ElasticNet()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.8891480300369239
# Training Accuracy: 88.17 %
# Training data Standard Deviation: 1.46 %
# r_2_score =  0.8884004119322245
# MSE =  0.2803549158724134
# RMSE =  0.078598878853828
# Compare with Predict and actual
#  [[1.   1.23]
#  [0.   0.35]
#  [2.   2.06]
#  [1.   1.32]
#  [1.   1.33]
#  [0.   0.35]
#  [1.   1.08]
#  [2.   1.75]
#  [1.   1.32]
#  [1.   1.09]]

# %% [markdown]
# # Polynomial

# %%
poly_features = PolynomialFeatures(degree=2, include_bias=True)
ploy_x_train = poly_features.fit_transform(x_train)
ploy_x_test = poly_features.fit_transform(x_test)

params = {
    'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'normalize': 'deprecated', 'positive': False
}
regressor = LinearRegression()
regressor.set_params(**params)
regressor.fit(ploy_x_train, y_train)
y_pred = regressor.predict(ploy_x_test)

print_summary(regressor, ploy_x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9486949445238945
# Training Accuracy: 91.39 %
# Training data Standard Deviation: 2.77 %
# r_2_score =  0.9192429064924624
# MSE =  0.238488377994569
# RMSE =  0.056876706438480425
# Compare with Predict and actual
#  [[1.   1.34]
#  [0.   0.09]
#  [2.   2.74]
#  [1.   1.4 ]
#  [1.   1.23]
#  [0.   0.1 ]
#  [1.   1.01]
#  [2.   1.88]
#  [1.   1.54]
#  [1.   1.1 ]]

# %% [markdown]
# # Support Vector

# %%
# kernel: {‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
# gamma: {`scale`, `auto`}
# C: The strength of the regularization is inversely proportional to C
params = {
    'C': 0.4, 'cache_size': 200, 'coef0': 0.0, 'degree': 3, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'rbf', 
    'max_iter': -1, 'shrinking': True, 'tol': 0.001, 'verbose': False
}
regressor = SVR()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9456054542155697
# Training Accuracy: 92.16 %
# Training data Standard Deviation: 3.22 %
# r_2_score =  0.9533803905438915
# MSE =  0.18120125252738942
# RMSE =  0.03283389391749475
# Compare with Predict and actual
#  [[1.   1.23]
#  [0.   0.07]
#  [2.   1.78]
#  [1.   1.39]
#  [1.   1.36]
#  [0.   0.09]
#  [1.   0.96]
#  [2.   1.97]
#  [1.   1.32]
#  [1.   1.06]]

# %% [markdown]
# # LinearSVR

# %%
# dual = False when n_samples > n_features
# C: The strength of the regularization is inversely proportional to C
params = {
    'C': 1.0, 'dual': True, 'epsilon': 0.0, 'fit_intercept': True, 'intercept_scaling': 1.0, 
    'loss': 'epsilon_insensitive', 'max_iter': 10000, 'random_state': None, 'tol': 0.0001, 'verbose': 0
}
regressor = LinearSVR()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9211384103614587
# Training Accuracy: 91.07 %
# Training data Standard Deviation: 2.13 %
# r_2_score =  0.929745432823939
# MSE =  0.222440652887066
# RMSE =  0.049479844056824186
# Compare with Predict and actual
#  [[1.   1.27]
#  [0.   0.15]
#  [2.   2.22]
#  [1.   1.39]
#  [1.   1.36]
#  [0.   0.22]
#  [1.   1.13]
#  [2.   1.88]
#  [1.   1.44]
#  [1.   1.14]]

# %% [markdown]
# # Random Forest

# %%
# criterion(The function to measure the quality of a split) : {“squared_error”, “absolute_error”, “friedman_mse”, “poisson”}
# max_depth : The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
# min_samples_split : The minimum number of samples required to split an internal node.
# bootstrap : Whether bootstrap samples are used when building trees. If False, the whole dataset is used to build each tree.
# oob_score : Whether to use out-of-bag samples to estimate the generalization score. Only available if bootstrap=True.
# ccp_alpha : The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed.
params = {
    'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 'auto', 
    'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 
    'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 
    'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False
}
regressor = RandomForestRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9884571568507408
# Training Accuracy: 93.82 %
# Training data Standard Deviation: 6.76 %
# r_2_score =  0.9934985250737464
# MSE =  0.06766791978789545
# RMSE =  0.004578947368421052
# Compare with Predict and actual
#  [[1.   1.23]
#  [0.   0.  ]
#  [2.   1.97]
#  [1.   1.  ]
#  [1.   1.28]
#  [0.   0.  ]
#  [1.   1.  ]
#  [2.   1.99]
#  [1.   1.11]
#  [1.   1.  ]]

# %% [markdown]
# # Decision Tree

# %%
# splitter : The strategy used to choose the split at each node.
params = {
    'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': None, 
    'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 
    'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'
}
regressor = DecisionTreeRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  1.0
# Training Accuracy: 90.62 %
# Training data Standard Deviation: 6.62 %
# r_2_score =  1.0
# MSE =  0.0
# RMSE =  0.0
# Compare with Predict and actual
#  [[1. 1.]
#  [0. 0.]
#  [2. 2.]
#  [1. 1.]
#  [1. 1.]
#  [0. 0.]
#  [1. 1.]
#  [2. 2.]
#  [1. 1.]
#  [1. 1.]]

# %% [markdown]
# # SGD

# %%
# penalty : {‘l2’, ‘l1’, ‘elasticnet’, None}
# alpha : The higher the value, the stronger the regularization.
# learning_rate : {constant, optimal, invscaling, adaptive}
# n_iter_no_change : Number of iterations with no improvement to wait before stopping fitting.
params = {
    'alpha': 0.0001, 'average': False, 'early_stopping': False, 'epsilon': 0.1, 'eta0': 0.01, 
    'fit_intercept': True, 'l1_ratio': 0.25, 'learning_rate': 'invscaling', 'loss': 'squared_error', 
    'max_iter': 1000, 'n_iter_no_change': 10, 'penalty': 'elasticnet', 'power_t': 0.25, 'random_state': None, 
    'shuffle': True, 'tol': 0.001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False
}
regressor = SGDRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.91376773366571
# Training Accuracy: 90.50 %
# Training data Standard Deviation: 2.16 %
# r_2_score =  0.923736112975819
# MSE =  0.23175886118836903
# RMSE =  0.0537121697393297
# Compare with Predict and actual
#  [[1.   1.3 ]
#  [0.   0.15]
#  [2.   2.35]
#  [1.   1.38]
#  [1.   1.47]
#  [0.   0.22]
#  [1.   1.1 ]
#  [2.   1.88]
#  [1.   1.54]
#  [1.   1.16]]

# %% [markdown]
# # Voting

# %%
r1 = LinearRegression()
r2 = RandomForestRegressor(n_estimators=10, random_state=1)

estimators = [
    ('r1', r1),
    ('r2', r2)
]

regressor = VotingRegressor(estimators=estimators)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9663109650788814
# Training Accuracy: 93.89 %
# Training data Standard Deviation: 3.89 %
# r_2_score =  0.974516797648923
# MSE =  0.13396886600068922
# RMSE =  0.01794765705751062
# Compare with Predict and actual
#  [[1.   1.26]
#  [0.   0.06]
#  [2.   2.07]
#  [1.   1.21]
#  [1.   1.28]
#  [0.   0.08]
#  [1.   1.07]
#  [2.   1.92]
#  [1.   1.22]
#  [1.   1.08]]

# %% [markdown]
# # Bagging

# %%
params = {
    'base_estimator': DecisionTreeRegressor(), 'bootstrap': True, 'bootstrap_features': False, 
    'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 10, 'n_jobs': None, 'oob_score': False, 
    'random_state': None, 'verbose': 0, 'warm_start': False
}
regressor = BaggingRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9897147055222236
# Training Accuracy: 92.00 %
# Training data Standard Deviation: 6.78 %
# r_2_score =  0.9981317600786628
# MSE =  0.03627381250550058
# RMSE =  0.0013157894736842105
# Compare with Predict and actual
#  [[1.  1.1]
#  [0.  0. ]
#  [2.  2. ]
#  [1.  1. ]
#  [1.  1. ]
#  [0.  0. ]
#  [1.  1. ]
#  [2.  2. ]
#  [1.  1. ]
#  [1.  1. ]]

# %% [markdown]
# # Stacking

# %%
estimators = [
    ('r1', Ridge()),
    ('r2', LinearRegression())
]

final_estimator = RandomForestRegressor(n_estimators=10, random_state=42)

regressor = StackingRegressor(
    estimators=estimators, final_estimator=final_estimator
)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9690069793069671
# Training Accuracy: 95.51 %
# Training data Standard Deviation: 7.54 %
# r_2_score =  0.9887905604719764
# MSE =  0.08885233166386386
# RMSE =  0.007894736842105263
# Compare with Predict and actual
#  [[1.  1. ]
#  [0.  0. ]
#  [2.  2. ]
#  [1.  1. ]
#  [1.  1. ]
#  [0.  0. ]
#  [1.  1. ]
#  [2.  2. ]
#  [1.  1.2]
#  [1.  1. ]]

# %% [markdown]
# # Gradient Boosting

# %%
params = {
    'alpha': 0.9, 'ccp_alpha': 0.0, 'criterion': 'friedman_mse', 'init': None, 'learning_rate': 0.1,
    'loss': 'squared_error', 'max_depth': 3, 'max_features': None, 'max_leaf_nodes': None, 
    'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0,
    'n_estimators': 100, 'n_iter_no_change': None, 'random_state': None, 'subsample': 1.0, 'tol': 0.0001,
    'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False
}
regressor = GradientBoostingRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9992469583377009
# Training Accuracy: 91.63 %
# Training data Standard Deviation: 6.54 %
# r_2_score =  0.9939411529848721
# MSE =  0.06532386509295227
# RMSE =  0.0042672073506822275
# Compare with Predict and actual
#  [[1.00e+00 1.10e+00]
#  [0.00e+00 4.56e-04]
#  [2.00e+00 1.93e+00]
#  [1.00e+00 1.02e+00]
#  [1.00e+00 1.01e+00]
#  [0.00e+00 4.56e-04]
#  [1.00e+00 1.01e+00]
#  [2.00e+00 1.98e+00]
#  [1.00e+00 1.36e+00]
#  [1.00e+00 9.98e-01]]

# %% [markdown]
# # HistGradientBoosting
#
# This estimator is much faster than GradientBoostingRegressor for big datasets (n_samples >= 10 000)

# %%
# loss : {‘squared_error’, ‘absolute_error’, ‘poisson’, ‘quantile’}
# max_bins : The maximum number of bins to use for non-missing values.
# validation_fraction : Proportion (or absolute size) of training data to set aside as validation data for early stopping. If None, early stopping is done on the training data.
# scoring : Scoring parameter to use for early stopping.
# interaction_cst : Specify interaction constraints, the sets of features which can interact with each other in child node splits.
# monotonic_cst : Monotonic constraint to enforce on each feature are specified using the {1, 0, -1} integer values.
params = {
    'categorical_features': None, 'early_stopping': 'auto', 'l2_regularization': 0.0, 'learning_rate': 0.1,
    'loss': 'squared_error', 'max_bins': 255, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31,
    'min_samples_leaf': 20, 'monotonic_cst': None, 'n_iter_no_change': 10, 'random_state': None,
    'scoring': 'loss', 'tol': 1e-07, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False
}
regressor = HistGradientBoostingRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9711117206105693
# Training Accuracy: 92.08 %
# Training data Standard Deviation: 6.50 %
# r_2_score =  0.9819071685213799
# MSE =  0.11288341746024777
# RMSE =  0.012742665937504572
# Compare with Predict and actual
#  [[ 1.00e+00  1.37e+00]
#  [ 0.00e+00 -9.52e-04]
#  [ 2.00e+00  2.07e+00]
#  [ 1.00e+00  1.20e+00]
#  [ 1.00e+00  1.32e+00]
#  [ 0.00e+00 -1.22e-02]
#  [ 1.00e+00  1.02e+00]
#  [ 2.00e+00  1.95e+00]
#  [ 1.00e+00  1.20e+00]
#  [ 1.00e+00  1.03e+00]]

# %% [markdown]
# # Extra Trees
#
# This class implements a meta estimator that fits a number of randomized decision trees (a.k.a. extra-trees) on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting.

# %%
params = {
    'bootstrap': False, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 
    'max_features': 'auto', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0,
    'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100,
    'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False
}
regressor = ExtraTreesRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  1.0
# Training Accuracy: 93.78 %
# Training data Standard Deviation: 6.19 %
# r_2_score =  0.9937937069813176
# MSE =  0.06611393674240665
# RMSE =  0.004371052631578948
# Compare with Predict and actual
#  [[1.   1.21]
#  [0.   0.06]
#  [2.   2.  ]
#  [1.   1.07]
#  [1.   1.17]
#  [0.   0.  ]
#  [1.   0.99]
#  [2.   1.97]
#  [1.   1.25]
#  [1.   1.  ]]

# %% [markdown]
# # PLS

# %%
params = {
    'copy': True, 'max_iter': 500, 'n_components': 2, 'scale': True, 'tol': 1e-06
}
regressor = PLSRegression()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9130707945053103
# Training Accuracy: 90.26 %
# Training data Standard Deviation: 2.25 %
# r_2_score =  0.915940046610332
# MSE =  0.24331643925208446
# RMSE =  0.0592028896103133
# Compare with Predict and actual
#  [[1.   1.33]
#  [0.   0.06]
#  [2.   2.33]
#  [1.   1.41]
#  [1.   1.45]
#  [0.   0.2 ]
#  [1.   1.16]
#  [2.   1.87]
#  [1.   1.63]
#  [1.   1.22]]

# %% [markdown]
# # XGBoost
#
#
# XGBoost does not support categorical variables natively, so it is necessary to encode them prior to training

# %%
# objective : {reg:linear, binary:logistic, multi:softmax, multi:softprob, reg:squarederror}
# base_score : The initial prediction score of all instances, global bias.
# booster : {gbtree, gblinear, dart} gbtree and dart use tree based models while gblinear uses linear functions.
# colsample_bylevel/colsample_bytree/colsample_bynode: This is a family of parameters for subsampling of columns.
# gamma : Minimum loss reduction required to make a further partition on a leaf node of the tree.
# Subsample[0-1] : Subsample ratio of the training instances. Setting it to 0.5 means that XGBoost would randomly sample half of the training data prior to growing trees. and this will prevent overfitting. Subsampling will occur once in every boosting iteration.
# reg_alpha : L1 regularization.
# reg_lambda : L2 regularization.
# scale_pos_weight : Control the balance of positive and negative weights, useful for unbalanced classes.
# n_estimators : Number of gradient boosted trees.
# num_parallel_tree : Used for boosting random forest.
# validate_parameters : Give warnings for unknown parameter.
# predictor : [cpu_predictor, gpu_predictor]  Force XGBoost to use specific predictor.
params = {
    'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'colsample_bylevel': None,
    'colsample_bynode': None, 'colsample_bytree': None, 'enable_categorical': False, 'gamma': None, 
    'gpu_id': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': None,
    'max_delta_step': None, 'max_depth': None, 'min_child_weight': None, 'missing': np.nan,
    'monotone_constraints': None, 'n_estimators': 100, 'n_jobs': None, 'num_parallel_tree': None,
    'predictor': None, 'random_state': None, 'reg_alpha': None, 'reg_lambda': None, 'scale_pos_weight': None,
    'subsample': None, 'tree_method': 'auto', 'validate_parameters': None, 'verbosity': None
}
regressor = XGBRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9999967006210447
# Training Accuracy: 90.08 %
# Training data Standard Deviation: 8.39 %
# r_2_score =  0.9918723975765179
# MSE =  0.07565856596810405
# RMSE =  0.005724218604349952
# Compare with Predict and actual
#  [[1.00e+00 1.19e+00]
#  [0.00e+00 6.71e-05]
#  [2.00e+00 1.95e+00]
#  [1.00e+00 1.14e+00]
#  [1.00e+00 9.02e-01]
#  [0.00e+00 6.71e-05]
#  [1.00e+00 1.00e+00]
#  [2.00e+00 2.01e+00]
#  [1.00e+00 1.28e+00]
#  [1.00e+00 1.00e+00]]

# %% [markdown]
# # AdaBoost

# %%
# loss : {‘linear’, ‘square’, ‘exponential’}
# learning_rate (0.0, inf): Weight applied to each regressor at each boosting iteration. A higher learning rate increases the contribution of each regressor.
params = {
    'base_estimator': DecisionTreeRegressor(max_depth=3), 
    'learning_rate': 1.0, 'loss': 'linear', 'n_estimators': 50, 'random_state': None
}
regressor = AdaBoostRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9705630482977163
# Training Accuracy: 91.27 %
# Training data Standard Deviation: 7.17 %
# r_2_score =  0.9995029555409282
# MSE =  0.018710030618869257
# RMSE =  0.00035006524575902505
# Compare with Predict and actual
#  [[1.   1.03]
#  [0.   0.  ]
#  [2.   2.  ]
#  [1.   1.03]
#  [1.   1.03]
#  [0.   0.  ]
#  [1.   1.  ]
#  [2.   2.  ]
#  [1.   1.09]
#  [1.   1.  ]]

# %% [markdown]
# # Light GBM
#
# - Light GBM grows tree vertically while other algorithm grows trees horizontally meaning that Light GBM grows tree leaf-wise while other algorithm grows level-wise.
# - it is not advisable to use LGBM on small datasets.
# - LGBM also supports GPU learning and thus data scientists are widely using LGBM for data science application development

# %%
# boosting_type : gbdt’, traditional Gradient Boosting Decision Tree. ‘dart’, Dropouts meet Multiple Additive Regression Trees. ‘rf’, Random Forest.
# subsample_for_bin : Number of samples for constructing bins.
# min_split_gain : Minimum loss reduction required to make a further partition on a leaf node of the tree.
params = {
    'boosting_type': 'gbdt', 'class_weight': None, 'colsample_bytree': 1.0, 'importance_type': 'split', 
    'learning_rate': 0.1, 'max_depth': -1, 'min_child_samples': 20, 'min_child_weight': 0.001, 
    'min_split_gain': 0.0, 'n_estimators': 100, 'n_jobs': -1, 'num_leaves': 31, 'objective': None, 
    'random_state': None, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'silent': 'warn', 'subsample': 1.0,
    'subsample_for_bin': 200000, 'subsample_freq': 0
}
regressor = LGBMRegressor()
regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# training_score =  0.9669729374919923
# Training Accuracy: 90.82 %
# Training data Standard Deviation: 7.64 %
# r_2_score =  0.96998083862817
# MSE =  0.1454039342533932
# RMSE =  0.021142304096365094
# Compare with Predict and actual
#  [[1.   1.4 ]
#  [0.   0.09]
#  [2.   2.08]
#  [1.   1.22]
#  [1.   1.31]
#  [0.   0.21]
#  [1.   1.1 ]
#  [2.   1.97]
#  [1.   1.2 ]
#  [1.   1.04]]

# %% [markdown]
# # Cat Boost

# %%
params = {
    'nan_mode': 'Min', 'eval_metric': 'RMSE', 'iterations': 1000, 'sampling_frequency': 'PerTree',
    'leaf_estimation_method': 'Newton', 'grow_policy': 'SymmetricTree', 'penalties_coefficient': 1,
    'boosting_type': 'Plain', 'model_shrink_mode': 'Constant', 'feature_border_type': 'GreedyLogSum', 
    'bayesian_matrix_reg': 0.10000000149011612, 'eval_fraction': 0, 'force_unit_auto_pair_weights': False,
    'l2_leaf_reg': 3, 'random_strength': 1, 'rsm': 1, 'boost_from_average': True, 'model_size_reg': 0.5,
    'pool_metainfo_options': {'tags': {}}, 'subsample': 0.800000011920929, 'use_best_model': False,
    'random_seed': 0, 'depth': 6, 'posterior_sampling': False, 'border_count': 254, 'classes_count': 0,
    'auto_class_weights': 'None', 'sparse_features_conflict_fraction': 0, 
    'leaf_estimation_backtracking': 'AnyImprovement', 'best_model_min_trees': 1, 'model_shrink_rate': 0,
    'min_data_in_leaf': 1, 'loss_function': 'RMSE', 'learning_rate': 0.028970999643206596,
    'score_function': 'Cosine', 'task_type': 'CPU', 'leaf_estimation_iterations': 1, 'bootstrap_type': 'MVS',
    'max_leaves': 64
}
regressor = CatBoostRegressor()
# regressor.set_params(**params)
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)

print_summary(regressor, x_train, y_train, y_test, y_pred)
# Out:
# Learning rate set to 0.028971
# 0:	learn: 0.7885316	total: 48.5ms	remaining: 48.5s
# 1:	learn: 0.7722834	total: 49.7ms	remaining: 24.8s
# 2:	learn: 0.7546522	total: 50.6ms	remaining: 16.8s
# 3:	learn: 0.7381380	total: 51.4ms	remaining: 12.8s
# 4:	learn: 0.7216270	total: 51.8ms	remaining: 10.3s
# 5:	learn: 0.7072162	total: 52.1ms	remaining: 8.63s
# 6:	learn: 0.6930156	total: 52.4ms	remaining: 7.43s
# 7:	learn: 0.6785189	total: 52.7ms	remaining: 6.53s
# 8:	learn: 0.6647331	total: 53ms	remaining: 5.83s
# 9:	learn: 0.6495870	total: 53.3ms	remaining: 5.27s
# 10:	learn: 0.6385574	total: 53.6ms	remaining: 4.82s
# 11:	learn: 0.6255637	total: 53.9ms	remaining: 4.43s
# 12:	learn: 0.6116135	total: 54.1ms	remaining: 4.11s
# 13:	learn: 0.5986482	total: 54.4ms	remaining: 3.83s
# 14:	learn: 0.5867086	total: 54.7ms	remaining: 3.59s
# 15:	learn: 0.5749941	total: 54.9ms	remaining: 3.38s
# 16:	learn: 0.5631658	total: 55.2ms	remaining: 3.19s
# 17:	learn: 0.5518121	total: 55.4ms	remaining: 3.02s
# 18:	learn: 0.5403781	total: 55.6ms	remaining: 2.87s
# 19:	learn: 0.5287875	total: 55.9ms	remaining: 2.74s
# 20:	learn: 0.5198844	total: 56.1ms	remaining: 2.62s
# 21:	learn: 0.5102262	total: 56.4ms	remaining: 2.51s
# 22:	learn: 0.4996222	total: 56.7ms	remaining: 2.41s
# 23:	learn: 0.4905770	total: 56.9ms	remaining: 2.31s
# 24:	learn: 0.4809873	total: 57.1ms	remaining: 2.23s
# 25:	learn: 0.4735537	total: 57.4ms	remaining: 2.15s
# 26:	learn: 0.4633444	total: 57.7ms	remaining: 2.08s
# 27:	learn: 0.4556186	total: 57.9ms	remaining: 2.01s
# 28:	learn: 0.4477182	total: 58.1ms	remaining: 1.95s
# 29:	learn: 0.4391726	total: 58.4ms	remaining: 1.89s
# 30:	learn: 0.4303610	total: 58.6ms	remaining: 1.83s
# 31:	learn: 0.4221631	total: 58.9ms	remaining: 1.78s
# 32:	learn: 0.4157808	total: 59.1ms	remaining: 1.73s
# 33:	learn: 0.4085188	total: 59.4ms	remaining: 1.69s
# 34:	learn: 0.4019826	total: 59.6ms	remaining: 1.64s
# 35:	learn: 0.3951329	total: 59.8ms	remaining: 1.6s
# 36:	learn: 0.3885917	total: 60.1ms	remaining: 1.56s
# 37:	learn: 0.3813391	total: 60.3ms	remaining: 1.53s
# 38:	learn: 0.3752579	total: 60.5ms	remaining: 1.49s
# 39:	learn: 0.3685847	total: 60.8ms	remaining: 1.46s
# 40:	learn: 0.3620869	total: 61ms	remaining: 1.43s
# 41:	learn: 0.3558154	total: 61.3ms	remaining: 1.4s
# 42:	learn: 0.3494543	total: 61.5ms	remaining: 1.37s
# 43:	learn: 0.3437359	total: 61.8ms	remaining: 1.34s
# 44:	learn: 0.3383884	total: 62ms	remaining: 1.31s
# 45:	learn: 0.3323303	total: 62.2ms	remaining: 1.29s
# 46:	learn: 0.3270088	total: 62.5ms	remaining: 1.27s
# 47:	learn: 0.3215683	total: 62.6ms	remaining: 1.24s
# 48:	learn: 0.3169621	total: 62.9ms	remaining: 1.22s
# 49:	learn: 0.3121293	total: 63.1ms	remaining: 1.2s
# 50:	learn: 0.3070977	total: 63.3ms	remaining: 1.18s
# 51:	learn: 0.3025243	total: 63.6ms	remaining: 1.16s
# 52:	learn: 0.2977748	total: 63.9ms	remaining: 1.14s
# 53:	learn: 0.2934901	total: 64.1ms	remaining: 1.12s
# 54:	learn: 0.2892277	total: 64.4ms	remaining: 1.11s
# 55:	learn: 0.2849774	total: 64.7ms	remaining: 1.09s
# 56:	learn: 0.2809344	total: 64.9ms	remaining: 1.07s
# 57:	learn: 0.2770472	total: 65.2ms	remaining: 1.06s
# 58:	learn: 0.2732085	total: 65.4ms	remaining: 1.04s
# 59:	learn: 0.2693498	total: 65.6ms	remaining: 1.03s
# 60:	learn: 0.2658574	total: 65.8ms	remaining: 1.01s
# 61:	learn: 0.2619977	total: 66.1ms	remaining: 1000ms
# 62:	learn: 0.2590147	total: 66.3ms	remaining: 986ms
# 63:	learn: 0.2552098	total: 66.5ms	remaining: 973ms
# 64:	learn: 0.2523811	total: 66.8ms	remaining: 961ms
# 65:	learn: 0.2487563	total: 67.1ms	remaining: 949ms
# 66:	learn: 0.2454202	total: 67.3ms	remaining: 937ms
# 67:	learn: 0.2424251	total: 67.6ms	remaining: 926ms
# 68:	learn: 0.2393226	total: 67.8ms	remaining: 915ms
# 69:	learn: 0.2364459	total: 68ms	remaining: 904ms
# 70:	learn: 0.2342058	total: 68.3ms	remaining: 893ms
# 71:	learn: 0.2316342	total: 68.5ms	remaining: 883ms
# 72:	learn: 0.2291829	total: 68.7ms	remaining: 873ms
# 73:	learn: 0.2266577	total: 69ms	remaining: 863ms
# 74:	learn: 0.2240946	total: 69.2ms	remaining: 854ms
# 75:	learn: 0.2213116	total: 69.4ms	remaining: 844ms
# 76:	learn: 0.2185117	total: 69.7ms	remaining: 835ms
# 77:	learn: 0.2161573	total: 69.9ms	remaining: 826ms
# 78:	learn: 0.2139111	total: 70.1ms	remaining: 818ms
# 79:	learn: 0.2119864	total: 70.4ms	remaining: 809ms
# 80:	learn: 0.2106396	total: 70.6ms	remaining: 801ms
# 81:	learn: 0.2080197	total: 70.8ms	remaining: 793ms
# 82:	learn: 0.2059701	total: 71.1ms	remaining: 785ms
# 83:	learn: 0.2035978	total: 71.3ms	remaining: 777ms
# 84:	learn: 0.2014138	total: 71.5ms	remaining: 770ms
# 85:	learn: 0.1997168	total: 71.7ms	remaining: 763ms
# 86:	learn: 0.1977662	total: 72ms	remaining: 756ms
# 87:	learn: 0.1963385	total: 72.3ms	remaining: 750ms
# 88:	learn: 0.1947716	total: 72.6ms	remaining: 743ms
# 89:	learn: 0.1929136	total: 72.8ms	remaining: 736ms
# 90:	learn: 0.1914763	total: 73.1ms	remaining: 730ms
# 91:	learn: 0.1895999	total: 73.3ms	remaining: 724ms
# 92:	learn: 0.1877211	total: 73.6ms	remaining: 718ms
# 93:	learn: 0.1861737	total: 73.9ms	remaining: 712ms
# 94:	learn: 0.1848739	total: 74.1ms	remaining: 706ms
# 95:	learn: 0.1834716	total: 74.3ms	remaining: 700ms
# 96:	learn: 0.1816931	total: 74.6ms	remaining: 694ms
# 97:	learn: 0.1801905	total: 74.8ms	remaining: 689ms
# 98:	learn: 0.1789614	total: 75.1ms	remaining: 683ms
# 99:	learn: 0.1770811	total: 75.3ms	remaining: 678ms
# 100:	learn: 0.1753882	total: 75.6ms	remaining: 673ms
# 101:	learn: 0.1744361	total: 75.8ms	remaining: 667ms
# 102:	learn: 0.1731567	total: 76.1ms	remaining: 663ms
# 103:	learn: 0.1719070	total: 76.4ms	remaining: 658ms
# 104:	learn: 0.1703717	total: 76.6ms	remaining: 653ms
# 105:	learn: 0.1694378	total: 76.9ms	remaining: 648ms
# 106:	learn: 0.1683647	total: 77.1ms	remaining: 644ms
# 107:	learn: 0.1669954	total: 77.4ms	remaining: 639ms
# 108:	learn: 0.1660160	total: 77.6ms	remaining: 634ms
# 109:	learn: 0.1646552	total: 77.8ms	remaining: 630ms
# 110:	learn: 0.1637733	total: 78.1ms	remaining: 625ms
# 111:	learn: 0.1622451	total: 78.3ms	remaining: 621ms
# 112:	learn: 0.1613930	total: 78.5ms	remaining: 617ms
# 113:	learn: 0.1597544	total: 78.8ms	remaining: 612ms
# 114:	learn: 0.1587947	total: 79ms	remaining: 608ms
# 115:	learn: 0.1580454	total: 79.3ms	remaining: 604ms
# 116:	learn: 0.1571214	total: 79.5ms	remaining: 600ms
# 117:	learn: 0.1564939	total: 79.6ms	remaining: 595ms
# 118:	learn: 0.1552246	total: 79.8ms	remaining: 591ms
# 119:	learn: 0.1544797	total: 80.1ms	remaining: 587ms
# 120:	learn: 0.1537330	total: 80.5ms	remaining: 585ms
# 121:	learn: 0.1529751	total: 80.8ms	remaining: 582ms
# 122:	learn: 0.1518187	total: 81ms	remaining: 578ms
# 123:	learn: 0.1506643	total: 81.4ms	remaining: 575ms
# 124:	learn: 0.1497304	total: 81.6ms	remaining: 571ms
# 125:	learn: 0.1492561	total: 81.8ms	remaining: 567ms
# 126:	learn: 0.1486037	total: 82.1ms	remaining: 564ms
# 127:	learn: 0.1479556	total: 82.3ms	remaining: 561ms
# 128:	learn: 0.1473449	total: 82.6ms	remaining: 558ms
# 129:	learn: 0.1461851	total: 82.9ms	remaining: 555ms
# 130:	learn: 0.1453266	total: 83.1ms	remaining: 551ms
# 131:	learn: 0.1447561	total: 83.4ms	remaining: 548ms
# 132:	learn: 0.1433617	total: 83.6ms	remaining: 545ms
# 133:	learn: 0.1428234	total: 83.9ms	remaining: 542ms
# 134:	learn: 0.1420450	total: 84.1ms	remaining: 539ms
# 135:	learn: 0.1410005	total: 84.3ms	remaining: 536ms
# 136:	learn: 0.1404862	total: 84.6ms	remaining: 533ms
# 137:	learn: 0.1397310	total: 84.8ms	remaining: 530ms
# 138:	learn: 0.1391933	total: 85ms	remaining: 527ms
# 139:	learn: 0.1386633	total: 85.3ms	remaining: 524ms
# 140:	learn: 0.1384199	total: 85.5ms	remaining: 521ms
# 141:	learn: 0.1380687	total: 85.8ms	remaining: 518ms
# 142:	learn: 0.1370609	total: 86ms	remaining: 515ms
# 143:	learn: 0.1360287	total: 86.2ms	remaining: 513ms
# 144:	learn: 0.1355577	total: 86.5ms	remaining: 510ms
# 145:	learn: 0.1347259	total: 86.7ms	remaining: 507ms
# 146:	learn: 0.1336756	total: 86.9ms	remaining: 504ms
# 147:	learn: 0.1329678	total: 87.2ms	remaining: 502ms
# 148:	learn: 0.1326812	total: 87.4ms	remaining: 499ms
# 149:	learn: 0.1323843	total: 87.7ms	remaining: 497ms
# 150:	learn: 0.1315272	total: 87.9ms	remaining: 494ms
# 151:	learn: 0.1306512	total: 88.1ms	remaining: 492ms
# 152:	learn: 0.1301923	total: 88.6ms	remaining: 490ms
# 153:	learn: 0.1298205	total: 88.9ms	remaining: 488ms
# 154:	learn: 0.1292889	total: 89.1ms	remaining: 486ms
# 155:	learn: 0.1279980	total: 89.4ms	remaining: 483ms
# 156:	learn: 0.1271734	total: 89.6ms	remaining: 481ms
# 157:	learn: 0.1266376	total: 89.8ms	remaining: 479ms
# 158:	learn: 0.1260027	total: 90.1ms	remaining: 476ms
# 159:	learn: 0.1253985	total: 90.3ms	remaining: 474ms
# 160:	learn: 0.1248139	total: 90.5ms	remaining: 472ms
# 161:	learn: 0.1240417	total: 90.8ms	remaining: 470ms
# 162:	learn: 0.1232456	total: 91ms	remaining: 467ms
# 163:	learn: 0.1230711	total: 91.2ms	remaining: 465ms
# 164:	learn: 0.1224663	total: 91.5ms	remaining: 463ms
# 165:	learn: 0.1222418	total: 91.7ms	remaining: 461ms
# 166:	learn: 0.1218672	total: 92ms	remaining: 459ms
# 167:	learn: 0.1216309	total: 92.2ms	remaining: 457ms
# 168:	learn: 0.1213693	total: 92.4ms	remaining: 455ms
# 169:	learn: 0.1206062	total: 92.7ms	remaining: 453ms
# 170:	learn: 0.1196084	total: 92.9ms	remaining: 451ms
# 171:	learn: 0.1190003	total: 93.2ms	remaining: 449ms
# 172:	learn: 0.1183188	total: 93.5ms	remaining: 447ms
# 173:	learn: 0.1177377	total: 93.7ms	remaining: 445ms
# 174:	learn: 0.1173790	total: 93.9ms	remaining: 443ms
# 175:	learn: 0.1169612	total: 94.2ms	remaining: 441ms
# 176:	learn: 0.1161276	total: 94.4ms	remaining: 439ms
# 177:	learn: 0.1155393	total: 95.5ms	remaining: 441ms
# 178:	learn: 0.1151179	total: 96.3ms	remaining: 442ms
# 179:	learn: 0.1142257	total: 97.5ms	remaining: 444ms
# 180:	learn: 0.1132415	total: 98ms	remaining: 444ms
# 181:	learn: 0.1130474	total: 100ms	remaining: 450ms
# 182:	learn: 0.1124171	total: 102ms	remaining: 457ms
# 183:	learn: 0.1116551	total: 103ms	remaining: 457ms
# 184:	learn: 0.1108817	total: 103ms	remaining: 456ms
# 185:	learn: 0.1106652	total: 104ms	remaining: 455ms
# 186:	learn: 0.1100334	total: 109ms	remaining: 473ms
# 187:	learn: 0.1098450	total: 109ms	remaining: 471ms
# 188:	learn: 0.1096515	total: 109ms	remaining: 469ms
# 189:	learn: 0.1091438	total: 110ms	remaining: 467ms
# 190:	learn: 0.1087499	total: 110ms	remaining: 465ms
# 191:	learn: 0.1081337	total: 110ms	remaining: 463ms
# 192:	learn: 0.1077144	total: 110ms	remaining: 461ms
# 193:	learn: 0.1071417	total: 111ms	remaining: 459ms
# 194:	learn: 0.1065282	total: 111ms	remaining: 458ms
# 195:	learn: 0.1058698	total: 111ms	remaining: 456ms
# 196:	learn: 0.1056289	total: 111ms	remaining: 454ms
# 197:	learn: 0.1049898	total: 112ms	remaining: 452ms
# 198:	learn: 0.1043616	total: 112ms	remaining: 451ms
# 199:	learn: 0.1041490	total: 112ms	remaining: 449ms
# 200:	learn: 0.1036415	total: 113ms	remaining: 450ms
# 201:	learn: 0.1034057	total: 115ms	remaining: 454ms
# 202:	learn: 0.1032599	total: 115ms	remaining: 453ms
# 203:	learn: 0.1028274	total: 116ms	remaining: 454ms
# 204:	learn: 0.1022733	total: 117ms	remaining: 453ms
# 205:	learn: 0.1019558	total: 117ms	remaining: 451ms
# 206:	learn: 0.1013017	total: 117ms	remaining: 450ms
# 207:	learn: 0.1009655	total: 118ms	remaining: 448ms
# 208:	learn: 0.1007807	total: 118ms	remaining: 446ms
# 209:	learn: 0.1004584	total: 118ms	remaining: 445ms
# 210:	learn: 0.1002860	total: 119ms	remaining: 443ms
# 211:	learn: 0.0997968	total: 119ms	remaining: 442ms
# 212:	learn: 0.0995695	total: 119ms	remaining: 440ms
# 213:	learn: 0.0990335	total: 119ms	remaining: 438ms
# 214:	learn: 0.0989055	total: 120ms	remaining: 437ms
# 215:	learn: 0.0987484	total: 120ms	remaining: 435ms
# 216:	learn: 0.0986189	total: 120ms	remaining: 434ms
# 217:	learn: 0.0980428	total: 120ms	remaining: 432ms
# 218:	learn: 0.0973209	total: 121ms	remaining: 431ms
# 219:	learn: 0.0968464	total: 121ms	remaining: 429ms
# 220:	learn: 0.0964656	total: 121ms	remaining: 428ms
# 221:	learn: 0.0958578	total: 122ms	remaining: 426ms
# 222:	learn: 0.0955075	total: 122ms	remaining: 425ms
# 223:	learn: 0.0953870	total: 122ms	remaining: 424ms
# 224:	learn: 0.0952814	total: 123ms	remaining: 423ms
# 225:	learn: 0.0950306	total: 123ms	remaining: 421ms
# 226:	learn: 0.0948598	total: 123ms	remaining: 420ms
# 227:	learn: 0.0943785	total: 123ms	remaining: 418ms
# 228:	learn: 0.0942377	total: 124ms	remaining: 417ms
# 229:	learn: 0.0937506	total: 124ms	remaining: 415ms
# 230:	learn: 0.0933275	total: 124ms	remaining: 414ms
# 231:	learn: 0.0932070	total: 125ms	remaining: 412ms
# 232:	learn: 0.0928584	total: 125ms	remaining: 411ms
# 233:	learn: 0.0926851	total: 125ms	remaining: 410ms
# 234:	learn: 0.0925179	total: 125ms	remaining: 408ms
# 235:	learn: 0.0919783	total: 126ms	remaining: 407ms
# 236:	learn: 0.0918090	total: 126ms	remaining: 405ms
# 237:	learn: 0.0916158	total: 126ms	remaining: 404ms
# 238:	learn: 0.0914806	total: 126ms	remaining: 403ms
# 239:	learn: 0.0913719	total: 127ms	remaining: 401ms
# 240:	learn: 0.0907164	total: 127ms	remaining: 400ms
# 241:	learn: 0.0904470	total: 127ms	remaining: 399ms
# 242:	learn: 0.0902990	total: 128ms	remaining: 398ms
# 243:	learn: 0.0901444	total: 128ms	remaining: 396ms
# 244:	learn: 0.0899663	total: 128ms	remaining: 395ms
# 245:	learn: 0.0898145	total: 128ms	remaining: 394ms
# 246:	learn: 0.0893892	total: 129ms	remaining: 392ms
# 247:	learn: 0.0887566	total: 129ms	remaining: 391ms
# 248:	learn: 0.0882174	total: 129ms	remaining: 390ms
# 249:	learn: 0.0876007	total: 130ms	remaining: 390ms
# 250:	learn: 0.0871455	total: 130ms	remaining: 388ms
# 251:	learn: 0.0865063	total: 130ms	remaining: 387ms
# 252:	learn: 0.0859931	total: 131ms	remaining: 386ms
# 253:	learn: 0.0858387	total: 131ms	remaining: 385ms
# 254:	learn: 0.0855775	total: 131ms	remaining: 384ms
# 255:	learn: 0.0854372	total: 132ms	remaining: 383ms
# 256:	learn: 0.0850462	total: 132ms	remaining: 382ms
# 257:	learn: 0.0849498	total: 132ms	remaining: 381ms
# 258:	learn: 0.0845858	total: 133ms	remaining: 379ms
# 259:	learn: 0.0840091	total: 133ms	remaining: 378ms
# 260:	learn: 0.0834424	total: 133ms	remaining: 377ms
# 261:	learn: 0.0832458	total: 133ms	remaining: 376ms
# 262:	learn: 0.0827210	total: 134ms	remaining: 375ms
# 263:	learn: 0.0822459	total: 134ms	remaining: 373ms
# 264:	learn: 0.0817221	total: 134ms	remaining: 372ms
# 265:	learn: 0.0816127	total: 134ms	remaining: 371ms
# 266:	learn: 0.0812537	total: 135ms	remaining: 370ms
# 267:	learn: 0.0807331	total: 135ms	remaining: 369ms
# 268:	learn: 0.0805792	total: 135ms	remaining: 368ms
# 269:	learn: 0.0804601	total: 136ms	remaining: 366ms
# 270:	learn: 0.0803283	total: 136ms	remaining: 365ms
# 271:	learn: 0.0799661	total: 136ms	remaining: 364ms
# 272:	learn: 0.0798177	total: 136ms	remaining: 363ms
# 273:	learn: 0.0793775	total: 137ms	remaining: 362ms
# 274:	learn: 0.0791511	total: 137ms	remaining: 361ms
# 275:	learn: 0.0790397	total: 137ms	remaining: 360ms
# 276:	learn: 0.0787006	total: 137ms	remaining: 359ms
# 277:	learn: 0.0785331	total: 138ms	remaining: 358ms
# 278:	learn: 0.0781791	total: 138ms	remaining: 357ms
# 279:	learn: 0.0779038	total: 138ms	remaining: 356ms
# 280:	learn: 0.0777871	total: 139ms	remaining: 355ms
# 281:	learn: 0.0776975	total: 139ms	remaining: 354ms
# 282:	learn: 0.0771926	total: 139ms	remaining: 353ms
# 283:	learn: 0.0770847	total: 139ms	remaining: 352ms
# 284:	learn: 0.0769596	total: 140ms	remaining: 351ms
# 285:	learn: 0.0768795	total: 140ms	remaining: 349ms
# 286:	learn: 0.0766903	total: 140ms	remaining: 349ms
# 287:	learn: 0.0764095	total: 141ms	remaining: 348ms
# 288:	learn: 0.0763069	total: 141ms	remaining: 347ms
# 289:	learn: 0.0760768	total: 141ms	remaining: 346ms
# 290:	learn: 0.0757449	total: 141ms	remaining: 344ms
# 291:	learn: 0.0753648	total: 142ms	remaining: 343ms
# 292:	learn: 0.0751573	total: 142ms	remaining: 342ms
# 293:	learn: 0.0749163	total: 142ms	remaining: 341ms
# 294:	learn: 0.0744995	total: 142ms	remaining: 340ms
# 295:	learn: 0.0743120	total: 143ms	remaining: 339ms
# 296:	learn: 0.0739630	total: 143ms	remaining: 338ms
# 297:	learn: 0.0735102	total: 143ms	remaining: 337ms
# 298:	learn: 0.0732793	total: 144ms	remaining: 336ms
# 299:	learn: 0.0729708	total: 144ms	remaining: 336ms
# 300:	learn: 0.0727296	total: 145ms	remaining: 337ms
# 301:	learn: 0.0722588	total: 146ms	remaining: 337ms
# 302:	learn: 0.0720338	total: 146ms	remaining: 336ms
# 303:	learn: 0.0716183	total: 146ms	remaining: 335ms
# 304:	learn: 0.0712392	total: 147ms	remaining: 334ms
# 305:	learn: 0.0710645	total: 147ms	remaining: 333ms
# 306:	learn: 0.0707952	total: 147ms	remaining: 332ms
# 307:	learn: 0.0706989	total: 148ms	remaining: 331ms
# 308:	learn: 0.0703385	total: 148ms	remaining: 330ms
# 309:	learn: 0.0702417	total: 148ms	remaining: 330ms
# 310:	learn: 0.0699923	total: 148ms	remaining: 329ms
# 311:	learn: 0.0698975	total: 149ms	remaining: 329ms
# 312:	learn: 0.0698004	total: 149ms	remaining: 328ms
# 313:	learn: 0.0697088	total: 150ms	remaining: 327ms
# 314:	learn: 0.0693721	total: 150ms	remaining: 326ms
# 315:	learn: 0.0692434	total: 150ms	remaining: 325ms
# 316:	learn: 0.0690376	total: 150ms	remaining: 324ms
# 317:	learn: 0.0686846	total: 151ms	remaining: 323ms
# 318:	learn: 0.0684710	total: 151ms	remaining: 322ms
# 319:	learn: 0.0681251	total: 151ms	remaining: 321ms
# 320:	learn: 0.0677838	total: 152ms	remaining: 320ms
# 321:	learn: 0.0673732	total: 152ms	remaining: 320ms
# 322:	learn: 0.0670311	total: 152ms	remaining: 319ms
# 323:	learn: 0.0666933	total: 152ms	remaining: 318ms
# 324:	learn: 0.0663475	total: 153ms	remaining: 317ms
# 325:	learn: 0.0660147	total: 153ms	remaining: 316ms
# 326:	learn: 0.0659219	total: 153ms	remaining: 316ms
# 327:	learn: 0.0658342	total: 154ms	remaining: 315ms
# 328:	learn: 0.0655528	total: 154ms	remaining: 314ms
# 329:	learn: 0.0652313	total: 154ms	remaining: 313ms
# 330:	learn: 0.0650298	total: 155ms	remaining: 312ms
# 331:	learn: 0.0646426	total: 155ms	remaining: 312ms
# 332:	learn: 0.0645369	total: 155ms	remaining: 311ms
# 333:	learn: 0.0643366	total: 155ms	remaining: 310ms
# 334:	learn: 0.0642505	total: 157ms	remaining: 311ms
# 335:	learn: 0.0639436	total: 157ms	remaining: 311ms
# 336:	learn: 0.0637127	total: 158ms	remaining: 310ms
# 337:	learn: 0.0635001	total: 158ms	remaining: 309ms
# 338:	learn: 0.0632578	total: 158ms	remaining: 308ms
# 339:	learn: 0.0629588	total: 158ms	remaining: 308ms
# 340:	learn: 0.0628738	total: 159ms	remaining: 307ms
# 341:	learn: 0.0625903	total: 159ms	remaining: 306ms
# 342:	learn: 0.0622655	total: 159ms	remaining: 305ms
# 343:	learn: 0.0619770	total: 160ms	remaining: 304ms
# 344:	learn: 0.0617116	total: 160ms	remaining: 303ms
# 345:	learn: 0.0614374	total: 160ms	remaining: 302ms
# 346:	learn: 0.0614021	total: 160ms	remaining: 301ms
# 347:	learn: 0.0612068	total: 160ms	remaining: 300ms
# 348:	learn: 0.0611721	total: 160ms	remaining: 299ms
# 349:	learn: 0.0609939	total: 161ms	remaining: 298ms
# 350:	learn: 0.0606864	total: 161ms	remaining: 297ms
# 351:	learn: 0.0604438	total: 161ms	remaining: 296ms
# 352:	learn: 0.0602412	total: 161ms	remaining: 295ms
# 353:	learn: 0.0600729	total: 161ms	remaining: 294ms
# 354:	learn: 0.0596120	total: 162ms	remaining: 294ms
# 355:	learn: 0.0595784	total: 162ms	remaining: 293ms
# 356:	learn: 0.0593923	total: 162ms	remaining: 292ms
# 357:	learn: 0.0592922	total: 162ms	remaining: 291ms
# 358:	learn: 0.0591031	total: 162ms	remaining: 290ms
# 359:	learn: 0.0588142	total: 163ms	remaining: 289ms
# 360:	learn: 0.0583703	total: 163ms	remaining: 288ms
# 361:	learn: 0.0581016	total: 163ms	remaining: 287ms
# 362:	learn: 0.0578311	total: 163ms	remaining: 286ms
# 363:	learn: 0.0575629	total: 163ms	remaining: 285ms
# 364:	learn: 0.0571569	total: 164ms	remaining: 284ms
# 365:	learn: 0.0569082	total: 164ms	remaining: 284ms
# 366:	learn: 0.0567402	total: 164ms	remaining: 283ms
# 367:	learn: 0.0564808	total: 164ms	remaining: 282ms
# 368:	learn: 0.0560704	total: 164ms	remaining: 281ms
# 369:	learn: 0.0556674	total: 164ms	remaining: 280ms
# 370:	learn: 0.0554227	total: 165ms	remaining: 279ms
# 371:	learn: 0.0553911	total: 165ms	remaining: 278ms
# 372:	learn: 0.0553636	total: 165ms	remaining: 277ms
# 373:	learn: 0.0549709	total: 165ms	remaining: 277ms
# 374:	learn: 0.0548637	total: 165ms	remaining: 276ms
# 375:	learn: 0.0546225	total: 166ms	remaining: 275ms
# 376:	learn: 0.0545976	total: 166ms	remaining: 274ms
# 377:	learn: 0.0543827	total: 166ms	remaining: 274ms
# 378:	learn: 0.0540039	total: 167ms	remaining: 274ms
# 379:	learn: 0.0537700	total: 167ms	remaining: 273ms
# 380:	learn: 0.0535784	total: 168ms	remaining: 272ms
# 381:	learn: 0.0535486	total: 168ms	remaining: 272ms
# 382:	learn: 0.0533961	total: 168ms	remaining: 271ms
# 383:	learn: 0.0533669	total: 168ms	remaining: 270ms
# 384:	learn: 0.0532107	total: 169ms	remaining: 269ms
# 385:	learn: 0.0529694	total: 169ms	remaining: 269ms
# 386:	learn: 0.0527194	total: 169ms	remaining: 268ms
# 387:	learn: 0.0526910	total: 169ms	remaining: 267ms
# 388:	learn: 0.0525015	total: 170ms	remaining: 267ms
# 389:	learn: 0.0521451	total: 171ms	remaining: 267ms
# 390:	learn: 0.0519349	total: 171ms	remaining: 266ms
# 391:	learn: 0.0517663	total: 171ms	remaining: 266ms
# 392:	learn: 0.0514722	total: 172ms	remaining: 265ms
# 393:	learn: 0.0513353	total: 172ms	remaining: 264ms
# 394:	learn: 0.0513094	total: 172ms	remaining: 264ms
# 395:	learn: 0.0510799	total: 173ms	remaining: 263ms
# 396:	learn: 0.0509259	total: 173ms	remaining: 263ms
# 397:	learn: 0.0508635	total: 173ms	remaining: 262ms
# 398:	learn: 0.0507293	total: 173ms	remaining: 261ms
# 399:	learn: 0.0505056	total: 173ms	remaining: 260ms
# 400:	learn: 0.0501855	total: 174ms	remaining: 259ms
# 401:	learn: 0.0501632	total: 174ms	remaining: 259ms
# 402:	learn: 0.0501361	total: 174ms	remaining: 258ms
# 403:	learn: 0.0499158	total: 174ms	remaining: 257ms
# 404:	learn: 0.0498923	total: 174ms	remaining: 256ms
# 405:	learn: 0.0497179	total: 175ms	remaining: 255ms
# 406:	learn: 0.0495125	total: 175ms	remaining: 255ms
# 407:	learn: 0.0493103	total: 175ms	remaining: 254ms
# 408:	learn: 0.0492857	total: 175ms	remaining: 253ms
# 409:	learn: 0.0490705	total: 175ms	remaining: 252ms
# 410:	learn: 0.0489208	total: 175ms	remaining: 251ms
# 411:	learn: 0.0487414	total: 176ms	remaining: 251ms
# 412:	learn: 0.0487174	total: 176ms	remaining: 250ms
# 413:	learn: 0.0486923	total: 176ms	remaining: 249ms
# 414:	learn: 0.0484851	total: 176ms	remaining: 249ms
# 415:	learn: 0.0483932	total: 177ms	remaining: 248ms
# 416:	learn: 0.0481270	total: 177ms	remaining: 247ms
# 417:	learn: 0.0479531	total: 177ms	remaining: 247ms
# 418:	learn: 0.0478946	total: 177ms	remaining: 246ms
# 419:	learn: 0.0478724	total: 177ms	remaining: 245ms
# 420:	learn: 0.0477882	total: 178ms	remaining: 244ms
# 421:	learn: 0.0475930	total: 178ms	remaining: 244ms
# 422:	learn: 0.0474240	total: 178ms	remaining: 243ms
# 423:	learn: 0.0472326	total: 178ms	remaining: 242ms
# 424:	learn: 0.0470286	total: 178ms	remaining: 241ms
# 425:	learn: 0.0468723	total: 179ms	remaining: 241ms
# 426:	learn: 0.0467931	total: 179ms	remaining: 240ms
# 427:	learn: 0.0467719	total: 179ms	remaining: 239ms
# 428:	learn: 0.0464674	total: 179ms	remaining: 238ms
# 429:	learn: 0.0462274	total: 179ms	remaining: 238ms
# 430:	learn: 0.0460468	total: 180ms	remaining: 237ms
# 431:	learn: 0.0459350	total: 180ms	remaining: 237ms
# 432:	learn: 0.0457710	total: 180ms	remaining: 236ms
# 433:	learn: 0.0457177	total: 181ms	remaining: 235ms
# 434:	learn: 0.0455710	total: 181ms	remaining: 235ms
# 435:	learn: 0.0454292	total: 181ms	remaining: 234ms
# 436:	learn: 0.0453530	total: 181ms	remaining: 234ms
# 437:	learn: 0.0452444	total: 182ms	remaining: 233ms
# 438:	learn: 0.0450226	total: 182ms	remaining: 232ms
# 439:	learn: 0.0448415	total: 182ms	remaining: 232ms
# 440:	learn: 0.0446861	total: 182ms	remaining: 231ms
# 441:	learn: 0.0446653	total: 183ms	remaining: 231ms
# 442:	learn: 0.0446461	total: 183ms	remaining: 230ms
# 443:	learn: 0.0445862	total: 183ms	remaining: 229ms
# 444:	learn: 0.0445070	total: 183ms	remaining: 229ms
# 445:	learn: 0.0443327	total: 184ms	remaining: 228ms
# 446:	learn: 0.0441872	total: 184ms	remaining: 228ms
# 447:	learn: 0.0440151	total: 184ms	remaining: 227ms
# 448:	learn: 0.0438574	total: 185ms	remaining: 227ms
# 449:	learn: 0.0437029	total: 185ms	remaining: 226ms
# 450:	learn: 0.0436516	total: 185ms	remaining: 225ms
# 451:	learn: 0.0435819	total: 185ms	remaining: 225ms
# 452:	learn: 0.0435213	total: 186ms	remaining: 224ms
# 453:	learn: 0.0433987	total: 186ms	remaining: 224ms
# 454:	learn: 0.0432536	total: 186ms	remaining: 223ms
# 455:	learn: 0.0431170	total: 186ms	remaining: 222ms
# 456:	learn: 0.0429340	total: 187ms	remaining: 222ms
# 457:	learn: 0.0428358	total: 187ms	remaining: 221ms
# 458:	learn: 0.0426551	total: 187ms	remaining: 221ms
# 459:	learn: 0.0424663	total: 188ms	remaining: 220ms
# 460:	learn: 0.0423306	total: 188ms	remaining: 220ms
# 461:	learn: 0.0422093	total: 188ms	remaining: 219ms
# 462:	learn: 0.0421356	total: 188ms	remaining: 218ms
# 463:	learn: 0.0419829	total: 189ms	remaining: 218ms
# 464:	learn: 0.0418359	total: 189ms	remaining: 217ms
# 465:	learn: 0.0417345	total: 189ms	remaining: 217ms
# 466:	learn: 0.0416898	total: 190ms	remaining: 216ms
# 467:	learn: 0.0416701	total: 190ms	remaining: 216ms
# 468:	learn: 0.0415238	total: 190ms	remaining: 215ms
# 469:	learn: 0.0414044	total: 190ms	remaining: 215ms
# 470:	learn: 0.0412734	total: 191ms	remaining: 214ms
# 471:	learn: 0.0411862	total: 191ms	remaining: 213ms
# 472:	learn: 0.0410067	total: 191ms	remaining: 213ms
# 473:	learn: 0.0408668	total: 191ms	remaining: 212ms
# 474:	learn: 0.0407620	total: 192ms	remaining: 212ms
# 475:	learn: 0.0407471	total: 192ms	remaining: 211ms
# 476:	learn: 0.0406286	total: 192ms	remaining: 211ms
# 477:	learn: 0.0404610	total: 193ms	remaining: 210ms
# 478:	learn: 0.0403953	total: 193ms	remaining: 210ms
# 479:	learn: 0.0402849	total: 193ms	remaining: 209ms
# 480:	learn: 0.0401395	total: 193ms	remaining: 209ms
# 481:	learn: 0.0399644	total: 194ms	remaining: 208ms
# 482:	learn: 0.0398131	total: 194ms	remaining: 208ms
# 483:	learn: 0.0397576	total: 195ms	remaining: 207ms
# 484:	learn: 0.0395065	total: 195ms	remaining: 207ms
# 485:	learn: 0.0393658	total: 195ms	remaining: 206ms
# 486:	learn: 0.0392598	total: 196ms	remaining: 206ms
# 487:	learn: 0.0392347	total: 196ms	remaining: 206ms
# 488:	learn: 0.0391497	total: 196ms	remaining: 205ms
# 489:	learn: 0.0389110	total: 197ms	remaining: 205ms
# 490:	learn: 0.0386703	total: 197ms	remaining: 204ms
# 491:	learn: 0.0385212	total: 197ms	remaining: 204ms
# 492:	learn: 0.0383895	total: 197ms	remaining: 203ms
# 493:	learn: 0.0381562	total: 198ms	remaining: 202ms
# 494:	learn: 0.0380756	total: 198ms	remaining: 202ms
# 495:	learn: 0.0379225	total: 198ms	remaining: 202ms
# 496:	learn: 0.0378248	total: 199ms	remaining: 201ms
# 497:	learn: 0.0376801	total: 199ms	remaining: 201ms
# 498:	learn: 0.0375067	total: 199ms	remaining: 200ms
# 499:	learn: 0.0373897	total: 200ms	remaining: 200ms
# 500:	learn: 0.0373736	total: 200ms	remaining: 199ms
# 501:	learn: 0.0372635	total: 200ms	remaining: 199ms
# 502:	learn: 0.0372014	total: 200ms	remaining: 198ms
# 503:	learn: 0.0370611	total: 201ms	remaining: 198ms
# 504:	learn: 0.0370448	total: 201ms	remaining: 197ms
# 505:	learn: 0.0369987	total: 201ms	remaining: 196ms
# 506:	learn: 0.0368298	total: 201ms	remaining: 196ms
# 507:	learn: 0.0367772	total: 202ms	remaining: 195ms
# 508:	learn: 0.0367397	total: 202ms	remaining: 195ms
# 509:	learn: 0.0367260	total: 202ms	remaining: 194ms
# 510:	learn: 0.0365795	total: 202ms	remaining: 193ms
# 511:	learn: 0.0364291	total: 202ms	remaining: 193ms
# 512:	learn: 0.0364149	total: 203ms	remaining: 192ms
# 513:	learn: 0.0362949	total: 203ms	remaining: 192ms
# 514:	learn: 0.0362820	total: 203ms	remaining: 191ms
# 515:	learn: 0.0362029	total: 203ms	remaining: 191ms
# 516:	learn: 0.0361449	total: 203ms	remaining: 190ms
# 517:	learn: 0.0360642	total: 204ms	remaining: 189ms
# 518:	learn: 0.0359906	total: 204ms	remaining: 189ms
# 519:	learn: 0.0359058	total: 204ms	remaining: 188ms
# 520:	learn: 0.0358448	total: 204ms	remaining: 188ms
# 521:	learn: 0.0357527	total: 204ms	remaining: 187ms
# 522:	learn: 0.0356611	total: 205ms	remaining: 187ms
# 523:	learn: 0.0355688	total: 205ms	remaining: 186ms
# 524:	learn: 0.0355093	total: 205ms	remaining: 186ms
# 525:	learn: 0.0353697	total: 206ms	remaining: 185ms
# 526:	learn: 0.0352276	total: 206ms	remaining: 185ms
# 527:	learn: 0.0350840	total: 206ms	remaining: 184ms
# 528:	learn: 0.0349882	total: 207ms	remaining: 184ms
# 529:	learn: 0.0349097	total: 207ms	remaining: 183ms
# 530:	learn: 0.0348266	total: 207ms	remaining: 183ms
# 531:	learn: 0.0347579	total: 207ms	remaining: 182ms
# 532:	learn: 0.0346667	total: 208ms	remaining: 182ms
# 533:	learn: 0.0345768	total: 208ms	remaining: 181ms
# 534:	learn: 0.0344419	total: 208ms	remaining: 181ms
# 535:	learn: 0.0343161	total: 208ms	remaining: 180ms
# 536:	learn: 0.0341921	total: 209ms	remaining: 180ms
# 537:	learn: 0.0340861	total: 209ms	remaining: 180ms
# 538:	learn: 0.0339399	total: 210ms	remaining: 179ms
# 539:	learn: 0.0337964	total: 210ms	remaining: 179ms
# 540:	learn: 0.0337483	total: 210ms	remaining: 178ms
# 541:	learn: 0.0336740	total: 210ms	remaining: 178ms
# 542:	learn: 0.0335848	total: 210ms	remaining: 177ms
# 543:	learn: 0.0334832	total: 211ms	remaining: 177ms
# 544:	learn: 0.0333247	total: 211ms	remaining: 176ms
# 545:	learn: 0.0331729	total: 211ms	remaining: 175ms
# 546:	learn: 0.0331232	total: 211ms	remaining: 175ms
# 547:	learn: 0.0330446	total: 211ms	remaining: 174ms
# 548:	learn: 0.0329639	total: 212ms	remaining: 174ms
# 549:	learn: 0.0328245	total: 212ms	remaining: 173ms
# 550:	learn: 0.0327228	total: 212ms	remaining: 173ms
# 551:	learn: 0.0325833	total: 212ms	remaining: 172ms
# 552:	learn: 0.0325382	total: 212ms	remaining: 172ms
# 553:	learn: 0.0324130	total: 212ms	remaining: 171ms
# 554:	learn: 0.0323054	total: 213ms	remaining: 170ms
# 555:	learn: 0.0322393	total: 213ms	remaining: 170ms
# 556:	learn: 0.0322265	total: 213ms	remaining: 169ms
# 557:	learn: 0.0322113	total: 213ms	remaining: 169ms
# 558:	learn: 0.0320316	total: 213ms	remaining: 168ms
# 559:	learn: 0.0319730	total: 214ms	remaining: 168ms
# 560:	learn: 0.0318994	total: 214ms	remaining: 167ms
# 561:	learn: 0.0318852	total: 214ms	remaining: 167ms
# 562:	learn: 0.0317575	total: 214ms	remaining: 166ms
# 563:	learn: 0.0316861	total: 214ms	remaining: 166ms
# 564:	learn: 0.0316053	total: 214ms	remaining: 165ms
# 565:	learn: 0.0314243	total: 215ms	remaining: 165ms
# 566:	learn: 0.0313979	total: 215ms	remaining: 164ms
# 567:	learn: 0.0312906	total: 215ms	remaining: 163ms
# 568:	learn: 0.0311143	total: 215ms	remaining: 163ms
# 569:	learn: 0.0310631	total: 215ms	remaining: 162ms
# 570:	learn: 0.0309581	total: 216ms	remaining: 162ms
# 571:	learn: 0.0308852	total: 216ms	remaining: 161ms
# 572:	learn: 0.0308434	total: 216ms	remaining: 161ms
# 573:	learn: 0.0308143	total: 217ms	remaining: 161ms
# 574:	learn: 0.0306437	total: 217ms	remaining: 160ms
# 575:	learn: 0.0306307	total: 217ms	remaining: 160ms
# 576:	learn: 0.0304931	total: 217ms	remaining: 159ms
# 577:	learn: 0.0304507	total: 218ms	remaining: 159ms
# 578:	learn: 0.0303863	total: 218ms	remaining: 158ms
# 579:	learn: 0.0303665	total: 218ms	remaining: 158ms
# 580:	learn: 0.0302876	total: 219ms	remaining: 158ms
# 581:	learn: 0.0301664	total: 219ms	remaining: 157ms
# 582:	learn: 0.0301288	total: 219ms	remaining: 157ms
# 583:	learn: 0.0300526	total: 219ms	remaining: 156ms
# 584:	learn: 0.0300392	total: 220ms	remaining: 156ms
# 585:	learn: 0.0299659	total: 220ms	remaining: 155ms
# 586:	learn: 0.0298323	total: 220ms	remaining: 155ms
# 587:	learn: 0.0297363	total: 220ms	remaining: 154ms
# 588:	learn: 0.0296050	total: 221ms	remaining: 154ms
# 589:	learn: 0.0295638	total: 221ms	remaining: 153ms
# 590:	learn: 0.0294938	total: 221ms	remaining: 153ms
# 591:	learn: 0.0294123	total: 221ms	remaining: 153ms
# 592:	learn: 0.0293642	total: 222ms	remaining: 152ms
# 593:	learn: 0.0292854	total: 222ms	remaining: 152ms
# 594:	learn: 0.0291916	total: 222ms	remaining: 151ms
# 595:	learn: 0.0291544	total: 222ms	remaining: 151ms
# 596:	learn: 0.0290592	total: 223ms	remaining: 150ms
# 597:	learn: 0.0290032	total: 223ms	remaining: 150ms
# 598:	learn: 0.0288802	total: 223ms	remaining: 149ms
# 599:	learn: 0.0288596	total: 223ms	remaining: 149ms
# 600:	learn: 0.0288496	total: 223ms	remaining: 148ms
# 601:	learn: 0.0288395	total: 224ms	remaining: 148ms
# 602:	learn: 0.0287496	total: 224ms	remaining: 147ms
# 603:	learn: 0.0287047	total: 224ms	remaining: 147ms
# 604:	learn: 0.0286234	total: 224ms	remaining: 147ms
# 605:	learn: 0.0285802	total: 225ms	remaining: 146ms
# 606:	learn: 0.0285459	total: 225ms	remaining: 146ms
# 607:	learn: 0.0284668	total: 225ms	remaining: 145ms
# 608:	learn: 0.0284225	total: 225ms	remaining: 145ms
# 609:	learn: 0.0283335	total: 226ms	remaining: 144ms
# 610:	learn: 0.0282515	total: 226ms	remaining: 144ms
# 611:	learn: 0.0282429	total: 226ms	remaining: 143ms
# 612:	learn: 0.0282119	total: 226ms	remaining: 143ms
# 613:	learn: 0.0281217	total: 227ms	remaining: 142ms
# 614:	learn: 0.0281096	total: 227ms	remaining: 142ms
# 615:	learn: 0.0279998	total: 227ms	remaining: 142ms
# 616:	learn: 0.0278798	total: 227ms	remaining: 141ms
# 617:	learn: 0.0278131	total: 228ms	remaining: 141ms
# 618:	learn: 0.0277868	total: 228ms	remaining: 140ms
# 619:	learn: 0.0277121	total: 228ms	remaining: 140ms
# 620:	learn: 0.0277020	total: 228ms	remaining: 139ms
# 621:	learn: 0.0275953	total: 229ms	remaining: 139ms
# 622:	learn: 0.0274870	total: 229ms	remaining: 138ms
# 623:	learn: 0.0274763	total: 229ms	remaining: 138ms
# 624:	learn: 0.0273916	total: 229ms	remaining: 138ms
# 625:	learn: 0.0273171	total: 229ms	remaining: 137ms
# 626:	learn: 0.0271940	total: 230ms	remaining: 137ms
# 627:	learn: 0.0271250	total: 230ms	remaining: 136ms
# 628:	learn: 0.0270566	total: 230ms	remaining: 136ms
# 629:	learn: 0.0269710	total: 230ms	remaining: 135ms
# 630:	learn: 0.0269256	total: 231ms	remaining: 135ms
# 631:	learn: 0.0268203	total: 231ms	remaining: 134ms
# 632:	learn: 0.0267648	total: 231ms	remaining: 134ms
# 633:	learn: 0.0267569	total: 231ms	remaining: 134ms
# 634:	learn: 0.0267190	total: 232ms	remaining: 133ms
# 635:	learn: 0.0266596	total: 232ms	remaining: 133ms
# 636:	learn: 0.0265817	total: 233ms	remaining: 133ms
# 637:	learn: 0.0265454	total: 233ms	remaining: 132ms
# 638:	learn: 0.0264428	total: 233ms	remaining: 132ms
# 639:	learn: 0.0263371	total: 233ms	remaining: 131ms
# 640:	learn: 0.0262579	total: 234ms	remaining: 131ms
# 641:	learn: 0.0262224	total: 234ms	remaining: 130ms
# 642:	learn: 0.0262175	total: 234ms	remaining: 130ms
# 643:	learn: 0.0261090	total: 234ms	remaining: 130ms
# 644:	learn: 0.0260345	total: 235ms	remaining: 129ms
# 645:	learn: 0.0259535	total: 235ms	remaining: 129ms
# 646:	learn: 0.0259012	total: 235ms	remaining: 128ms
# 647:	learn: 0.0258380	total: 235ms	remaining: 128ms
# 648:	learn: 0.0258301	total: 236ms	remaining: 127ms
# 649:	learn: 0.0257220	total: 236ms	remaining: 127ms
# 650:	learn: 0.0255880	total: 236ms	remaining: 127ms
# 651:	learn: 0.0255819	total: 236ms	remaining: 126ms
# 652:	learn: 0.0255717	total: 237ms	remaining: 126ms
# 653:	learn: 0.0255592	total: 237ms	remaining: 125ms
# 654:	learn: 0.0254741	total: 237ms	remaining: 125ms
# 655:	learn: 0.0253479	total: 237ms	remaining: 124ms
# 656:	learn: 0.0253154	total: 238ms	remaining: 124ms
# 657:	learn: 0.0252414	total: 238ms	remaining: 124ms
# 658:	learn: 0.0252170	total: 238ms	remaining: 123ms
# 659:	learn: 0.0251234	total: 238ms	remaining: 123ms
# 660:	learn: 0.0250171	total: 239ms	remaining: 122ms
# 661:	learn: 0.0249419	total: 239ms	remaining: 122ms
# 662:	learn: 0.0248819	total: 239ms	remaining: 121ms
# 663:	learn: 0.0248717	total: 239ms	remaining: 121ms
# 664:	learn: 0.0247965	total: 239ms	remaining: 121ms
# 665:	learn: 0.0247870	total: 240ms	remaining: 120ms
# 666:	learn: 0.0247764	total: 240ms	remaining: 120ms
# 667:	learn: 0.0247642	total: 240ms	remaining: 119ms
# 668:	learn: 0.0247433	total: 240ms	remaining: 119ms
# 669:	learn: 0.0246902	total: 241ms	remaining: 119ms
# 670:	learn: 0.0246668	total: 241ms	remaining: 118ms
# 671:	learn: 0.0246575	total: 241ms	remaining: 118ms
# 672:	learn: 0.0245464	total: 241ms	remaining: 117ms
# 673:	learn: 0.0244581	total: 242ms	remaining: 117ms
# 674:	learn: 0.0243970	total: 242ms	remaining: 116ms
# 675:	learn: 0.0243657	total: 242ms	remaining: 116ms
# 676:	learn: 0.0243422	total: 242ms	remaining: 116ms
# 677:	learn: 0.0242322	total: 243ms	remaining: 115ms
# 678:	learn: 0.0241441	total: 243ms	remaining: 115ms
# 679:	learn: 0.0241087	total: 243ms	remaining: 114ms
# 680:	learn: 0.0240389	total: 243ms	remaining: 114ms
# 681:	learn: 0.0240211	total: 244ms	remaining: 114ms
# 682:	learn: 0.0238832	total: 244ms	remaining: 113ms
# 683:	learn: 0.0238757	total: 244ms	remaining: 113ms
# 684:	learn: 0.0237852	total: 244ms	remaining: 112ms
# 685:	learn: 0.0236972	total: 245ms	remaining: 112ms
# 686:	learn: 0.0236674	total: 245ms	remaining: 112ms
# 687:	learn: 0.0236574	total: 245ms	remaining: 111ms
# 688:	learn: 0.0235714	total: 245ms	remaining: 111ms
# 689:	learn: 0.0235630	total: 245ms	remaining: 110ms
# 690:	learn: 0.0235381	total: 246ms	remaining: 110ms
# 691:	learn: 0.0234806	total: 246ms	remaining: 109ms
# 692:	learn: 0.0234133	total: 246ms	remaining: 109ms
# 693:	learn: 0.0233773	total: 246ms	remaining: 109ms
# 694:	learn: 0.0233319	total: 247ms	remaining: 108ms
# 695:	learn: 0.0232757	total: 247ms	remaining: 108ms
# 696:	learn: 0.0232245	total: 247ms	remaining: 107ms
# 697:	learn: 0.0230914	total: 247ms	remaining: 107ms
# 698:	learn: 0.0230643	total: 248ms	remaining: 107ms
# 699:	learn: 0.0230122	total: 248ms	remaining: 106ms
# 700:	learn: 0.0230042	total: 249ms	remaining: 106ms
# 701:	learn: 0.0228913	total: 249ms	remaining: 106ms
# 702:	learn: 0.0228625	total: 249ms	remaining: 105ms
# 703:	learn: 0.0227725	total: 249ms	remaining: 105ms
# 704:	learn: 0.0227465	total: 249ms	remaining: 104ms
# 705:	learn: 0.0227399	total: 250ms	remaining: 104ms
# 706:	learn: 0.0226164	total: 250ms	remaining: 104ms
# 707:	learn: 0.0226087	total: 250ms	remaining: 103ms
# 708:	learn: 0.0224938	total: 250ms	remaining: 103ms
# 709:	learn: 0.0224867	total: 251ms	remaining: 102ms
# 710:	learn: 0.0224798	total: 251ms	remaining: 102ms
# 711:	learn: 0.0224267	total: 251ms	remaining: 102ms
# 712:	learn: 0.0224169	total: 251ms	remaining: 101ms
# 713:	learn: 0.0223182	total: 252ms	remaining: 101ms
# 714:	learn: 0.0222368	total: 252ms	remaining: 100ms
# 715:	learn: 0.0221467	total: 252ms	remaining: 99.9ms
# 716:	learn: 0.0221196	total: 252ms	remaining: 99.5ms
# 717:	learn: 0.0221121	total: 252ms	remaining: 99.2ms
# 718:	learn: 0.0220340	total: 253ms	remaining: 98.8ms
# 719:	learn: 0.0219605	total: 253ms	remaining: 98.4ms
# 720:	learn: 0.0219548	total: 253ms	remaining: 98ms
# 721:	learn: 0.0218628	total: 253ms	remaining: 97.6ms
# 722:	learn: 0.0218184	total: 254ms	remaining: 97.2ms
# 723:	learn: 0.0217782	total: 255ms	remaining: 97.1ms
# 724:	learn: 0.0217005	total: 255ms	remaining: 96.7ms
# 725:	learn: 0.0216392	total: 255ms	remaining: 96.3ms
# 726:	learn: 0.0215704	total: 255ms	remaining: 95.9ms
# 727:	learn: 0.0214827	total: 256ms	remaining: 95.6ms
# 728:	learn: 0.0214154	total: 256ms	remaining: 95.2ms
# 729:	learn: 0.0214088	total: 257ms	remaining: 95ms
# 730:	learn: 0.0213883	total: 257ms	remaining: 94.7ms
# 731:	learn: 0.0213620	total: 257ms	remaining: 94.3ms
# 732:	learn: 0.0213034	total: 258ms	remaining: 93.9ms
# 733:	learn: 0.0212779	total: 258ms	remaining: 93.5ms
# 734:	learn: 0.0212020	total: 258ms	remaining: 93.1ms
# 735:	learn: 0.0211438	total: 259ms	remaining: 92.8ms
# 736:	learn: 0.0210989	total: 259ms	remaining: 92.4ms
# 737:	learn: 0.0210736	total: 259ms	remaining: 92ms
# 738:	learn: 0.0210140	total: 260ms	remaining: 91.7ms
# 739:	learn: 0.0209717	total: 260ms	remaining: 91.3ms
# 740:	learn: 0.0209133	total: 260ms	remaining: 90.9ms
# 741:	learn: 0.0208721	total: 260ms	remaining: 90.5ms
# 742:	learn: 0.0208183	total: 261ms	remaining: 90.2ms
# 743:	learn: 0.0207528	total: 261ms	remaining: 89.8ms
# 744:	learn: 0.0207456	total: 261ms	remaining: 89.4ms
# 745:	learn: 0.0207311	total: 261ms	remaining: 89ms
# 746:	learn: 0.0207248	total: 262ms	remaining: 88.6ms
# 747:	learn: 0.0206941	total: 262ms	remaining: 88.3ms
# 748:	learn: 0.0206880	total: 262ms	remaining: 87.9ms
# 749:	learn: 0.0205832	total: 263ms	remaining: 87.5ms
# 750:	learn: 0.0205050	total: 263ms	remaining: 87.1ms
# 751:	learn: 0.0204200	total: 263ms	remaining: 86.8ms
# 752:	learn: 0.0203680	total: 263ms	remaining: 86.4ms
# 753:	learn: 0.0203624	total: 264ms	remaining: 86ms
# 754:	learn: 0.0203063	total: 264ms	remaining: 85.6ms
# 755:	learn: 0.0202169	total: 264ms	remaining: 85.3ms
# 756:	learn: 0.0202102	total: 264ms	remaining: 84.9ms
# 757:	learn: 0.0201185	total: 265ms	remaining: 84.5ms
# 758:	learn: 0.0200460	total: 265ms	remaining: 84.1ms
# 759:	learn: 0.0200276	total: 265ms	remaining: 83.8ms
# 760:	learn: 0.0199984	total: 265ms	remaining: 83.4ms
# 761:	learn: 0.0199853	total: 266ms	remaining: 83ms
# 762:	learn: 0.0198981	total: 266ms	remaining: 82.6ms
# 763:	learn: 0.0198931	total: 266ms	remaining: 82.3ms
# 764:	learn: 0.0198095	total: 267ms	remaining: 81.9ms
# 765:	learn: 0.0197911	total: 267ms	remaining: 81.5ms
# 766:	learn: 0.0197347	total: 267ms	remaining: 81.2ms
# 767:	learn: 0.0197163	total: 267ms	remaining: 80.8ms
# 768:	learn: 0.0196412	total: 268ms	remaining: 80.4ms
# 769:	learn: 0.0196040	total: 268ms	remaining: 80ms
# 770:	learn: 0.0195975	total: 268ms	remaining: 79.7ms
# 771:	learn: 0.0195927	total: 268ms	remaining: 79.3ms
# 772:	learn: 0.0195862	total: 269ms	remaining: 78.9ms
# 773:	learn: 0.0195756	total: 269ms	remaining: 78.5ms
# 774:	learn: 0.0195703	total: 269ms	remaining: 78.2ms
# 775:	learn: 0.0194875	total: 269ms	remaining: 77.8ms
# 776:	learn: 0.0194823	total: 270ms	remaining: 77.4ms
# 777:	learn: 0.0194722	total: 270ms	remaining: 77ms
# 778:	learn: 0.0194671	total: 270ms	remaining: 76.7ms
# 779:	learn: 0.0194611	total: 271ms	remaining: 76.3ms
# 780:	learn: 0.0194059	total: 271ms	remaining: 75.9ms
# 781:	learn: 0.0193352	total: 271ms	remaining: 75.6ms
# 782:	learn: 0.0192587	total: 271ms	remaining: 75.2ms
# 783:	learn: 0.0191861	total: 272ms	remaining: 74.8ms
# 784:	learn: 0.0191762	total: 272ms	remaining: 74.6ms
# 785:	learn: 0.0191693	total: 273ms	remaining: 74.2ms
# 786:	learn: 0.0191641	total: 273ms	remaining: 73.9ms
# 787:	learn: 0.0191145	total: 273ms	remaining: 73.5ms
# 788:	learn: 0.0191014	total: 273ms	remaining: 73.1ms
# 789:	learn: 0.0190861	total: 274ms	remaining: 72.8ms
# 790:	learn: 0.0190801	total: 274ms	remaining: 72.4ms
# 791:	learn: 0.0190737	total: 274ms	remaining: 72ms
# 792:	learn: 0.0190547	total: 275ms	remaining: 71.7ms
# 793:	learn: 0.0190503	total: 275ms	remaining: 71.3ms
# 794:	learn: 0.0190188	total: 275ms	remaining: 70.9ms
# 795:	learn: 0.0189515	total: 275ms	remaining: 70.6ms
# 796:	learn: 0.0188723	total: 276ms	remaining: 70.2ms
# 797:	learn: 0.0188048	total: 276ms	remaining: 69.8ms
# 798:	learn: 0.0187689	total: 276ms	remaining: 69.5ms
# 799:	learn: 0.0187092	total: 276ms	remaining: 69.1ms
# 800:	learn: 0.0186836	total: 277ms	remaining: 68.7ms
# 801:	learn: 0.0186794	total: 277ms	remaining: 68.4ms
# 802:	learn: 0.0185883	total: 277ms	remaining: 68ms
# 803:	learn: 0.0184965	total: 277ms	remaining: 67.6ms
# 804:	learn: 0.0184278	total: 278ms	remaining: 67.3ms
# 805:	learn: 0.0183793	total: 278ms	remaining: 66.9ms
# 806:	learn: 0.0183158	total: 278ms	remaining: 66.5ms
# 807:	learn: 0.0182981	total: 279ms	remaining: 66.2ms
# 808:	learn: 0.0182329	total: 279ms	remaining: 65.8ms
# 809:	learn: 0.0181748	total: 279ms	remaining: 65.5ms
# 810:	learn: 0.0180977	total: 279ms	remaining: 65.1ms
# 811:	learn: 0.0180804	total: 280ms	remaining: 64.7ms
# 812:	learn: 0.0180605	total: 280ms	remaining: 64.4ms
# 813:	learn: 0.0180557	total: 280ms	remaining: 64ms
# 814:	learn: 0.0180245	total: 280ms	remaining: 63.7ms
# 815:	learn: 0.0179923	total: 281ms	remaining: 63.3ms
# 816:	learn: 0.0179366	total: 281ms	remaining: 63ms
# 817:	learn: 0.0179236	total: 281ms	remaining: 62.6ms
# 818:	learn: 0.0179067	total: 282ms	remaining: 62.2ms
# 819:	learn: 0.0178339	total: 282ms	remaining: 61.9ms
# 820:	learn: 0.0178292	total: 282ms	remaining: 61.5ms
# 821:	learn: 0.0177686	total: 283ms	remaining: 61.2ms
# 822:	learn: 0.0177513	total: 283ms	remaining: 60.8ms
# 823:	learn: 0.0177328	total: 283ms	remaining: 60.5ms
# 824:	learn: 0.0177281	total: 284ms	remaining: 60.2ms
# 825:	learn: 0.0176500	total: 284ms	remaining: 59.8ms
# 826:	learn: 0.0175746	total: 285ms	remaining: 59.5ms
# 827:	learn: 0.0175124	total: 285ms	remaining: 59.3ms
# 828:	learn: 0.0175074	total: 286ms	remaining: 58.9ms
# 829:	learn: 0.0175028	total: 286ms	remaining: 58.6ms
# 830:	learn: 0.0174471	total: 286ms	remaining: 58.2ms
# 831:	learn: 0.0173984	total: 287ms	remaining: 57.9ms
# 832:	learn: 0.0173806	total: 287ms	remaining: 57.5ms
# 833:	learn: 0.0173664	total: 287ms	remaining: 57.2ms
# 834:	learn: 0.0173622	total: 288ms	remaining: 56.8ms
# 835:	learn: 0.0173186	total: 288ms	remaining: 56.5ms
# 836:	learn: 0.0172643	total: 288ms	remaining: 56.1ms
# 837:	learn: 0.0172598	total: 288ms	remaining: 55.8ms
# 838:	learn: 0.0172299	total: 289ms	remaining: 55.4ms
# 839:	learn: 0.0171779	total: 289ms	remaining: 55.1ms
# 840:	learn: 0.0171730	total: 290ms	remaining: 54.8ms
# 841:	learn: 0.0171168	total: 290ms	remaining: 54.4ms
# 842:	learn: 0.0170770	total: 290ms	remaining: 54.1ms
# 843:	learn: 0.0170718	total: 291ms	remaining: 53.7ms
# 844:	learn: 0.0170061	total: 291ms	remaining: 53.4ms
# 845:	learn: 0.0169664	total: 291ms	remaining: 53ms
# 846:	learn: 0.0168900	total: 292ms	remaining: 52.7ms
# 847:	learn: 0.0168180	total: 292ms	remaining: 52.3ms
# 848:	learn: 0.0167357	total: 292ms	remaining: 52ms
# 849:	learn: 0.0166790	total: 292ms	remaining: 51.6ms
# 850:	learn: 0.0166214	total: 293ms	remaining: 51.2ms
# 851:	learn: 0.0166105	total: 293ms	remaining: 50.9ms
# 852:	learn: 0.0165963	total: 293ms	remaining: 50.5ms
# 853:	learn: 0.0165922	total: 294ms	remaining: 50.2ms
# 854:	learn: 0.0165791	total: 294ms	remaining: 49.8ms
# 855:	learn: 0.0165698	total: 294ms	remaining: 49.5ms
# 856:	learn: 0.0165624	total: 294ms	remaining: 49.1ms
# 857:	learn: 0.0165516	total: 295ms	remaining: 48.8ms
# 858:	learn: 0.0165342	total: 295ms	remaining: 48.4ms
# 859:	learn: 0.0165296	total: 295ms	remaining: 48ms
# 860:	learn: 0.0164611	total: 295ms	remaining: 47.7ms
# 861:	learn: 0.0164570	total: 296ms	remaining: 47.3ms
# 862:	learn: 0.0164532	total: 296ms	remaining: 47ms
# 863:	learn: 0.0164101	total: 296ms	remaining: 46.6ms
# 864:	learn: 0.0163680	total: 296ms	remaining: 46.2ms
# 865:	learn: 0.0163213	total: 297ms	remaining: 45.9ms
# 866:	learn: 0.0162632	total: 297ms	remaining: 45.5ms
# 867:	learn: 0.0162210	total: 297ms	remaining: 45.2ms
# 868:	learn: 0.0161396	total: 297ms	remaining: 44.8ms
# 869:	learn: 0.0161337	total: 298ms	remaining: 44.5ms
# 870:	learn: 0.0161291	total: 298ms	remaining: 44.1ms
# 871:	learn: 0.0161147	total: 298ms	remaining: 43.8ms
# 872:	learn: 0.0160433	total: 298ms	remaining: 43.4ms
# 873:	learn: 0.0160167	total: 299ms	remaining: 43.1ms
# 874:	learn: 0.0160127	total: 299ms	remaining: 42.7ms
# 875:	learn: 0.0160091	total: 299ms	remaining: 42.4ms
# 876:	learn: 0.0160058	total: 300ms	remaining: 42ms
# 877:	learn: 0.0160022	total: 300ms	remaining: 41.7ms
# 878:	learn: 0.0159475	total: 300ms	remaining: 41.3ms
# 879:	learn: 0.0158912	total: 301ms	remaining: 41ms
# 880:	learn: 0.0158804	total: 301ms	remaining: 40.6ms
# 881:	learn: 0.0158316	total: 301ms	remaining: 40.3ms
# 882:	learn: 0.0158278	total: 302ms	remaining: 40ms
# 883:	learn: 0.0158085	total: 306ms	remaining: 40.1ms
# 884:	learn: 0.0158047	total: 306ms	remaining: 39.8ms
# 885:	learn: 0.0157692	total: 307ms	remaining: 39.6ms
# 886:	learn: 0.0156961	total: 308ms	remaining: 39.2ms
# 887:	learn: 0.0156920	total: 309ms	remaining: 39ms
# 888:	learn: 0.0156462	total: 310ms	remaining: 38.7ms
# 889:	learn: 0.0156425	total: 311ms	remaining: 38.4ms
# 890:	learn: 0.0156083	total: 311ms	remaining: 38.1ms
# 891:	learn: 0.0156050	total: 312ms	remaining: 37.7ms
# 892:	learn: 0.0155522	total: 312ms	remaining: 37.4ms
# 893:	learn: 0.0155095	total: 312ms	remaining: 37ms
# 894:	learn: 0.0155060	total: 312ms	remaining: 36.6ms
# 895:	learn: 0.0155026	total: 313ms	remaining: 36.3ms
# 896:	learn: 0.0154974	total: 313ms	remaining: 35.9ms
# 897:	learn: 0.0154358	total: 313ms	remaining: 35.6ms
# 898:	learn: 0.0154326	total: 313ms	remaining: 35.2ms
# 899:	learn: 0.0154296	total: 314ms	remaining: 34.8ms
# 900:	learn: 0.0154142	total: 314ms	remaining: 34.5ms
# 901:	learn: 0.0154108	total: 314ms	remaining: 34.1ms
# 902:	learn: 0.0153810	total: 314ms	remaining: 33.8ms
# 903:	learn: 0.0153476	total: 314ms	remaining: 33.4ms
# 904:	learn: 0.0153001	total: 315ms	remaining: 33ms
# 905:	learn: 0.0152855	total: 315ms	remaining: 32.7ms
# 906:	learn: 0.0152822	total: 315ms	remaining: 32.3ms
# 907:	learn: 0.0152790	total: 315ms	remaining: 32ms
# 908:	learn: 0.0152089	total: 316ms	remaining: 31.6ms
# 909:	learn: 0.0152051	total: 316ms	remaining: 31.2ms
# 910:	learn: 0.0151797	total: 316ms	remaining: 30.9ms
# 911:	learn: 0.0151518	total: 316ms	remaining: 30.5ms
# 912:	learn: 0.0150809	total: 317ms	remaining: 30.2ms
# 913:	learn: 0.0150701	total: 317ms	remaining: 29.8ms
# 914:	learn: 0.0150411	total: 317ms	remaining: 29.5ms
# 915:	learn: 0.0150381	total: 317ms	remaining: 29.1ms
# 916:	learn: 0.0149820	total: 318ms	remaining: 28.7ms
# 917:	learn: 0.0149131	total: 318ms	remaining: 28.4ms
# ...
# 703:	learn: 0.0212821	total: 197ms	remaining: 82.9ms
# 704:	learn: 0.0212385	total: 197ms	remaining: 82.6ms
# 705:	learn: 0.0212185	total: 198ms	remaining: 82.3ms
# 706:	learn: 0.0212016	total: 198ms	remaining: 82ms
# 707:	learn: 0.0211820	total: 198ms	remaining: 81.7ms
# 708:	learn: 0.0211009	total: 198ms	remaining: 81.4ms
# 709:	learn: 0.0210759	total: 199ms	remaining: 81.1ms
# 710:	learn: 0.0210349	total: 199ms	remaining: 80.9ms
# 711:	learn: 0.0210184	total: 199ms	remaining: 80.6ms
# 712:	learn: 0.0209752	total: 200ms	remaining: 80.3ms
# 713:	learn: 0.0209593	total: 200ms	remaining: 80ms
# 714:	learn: 0.0209437	total: 200ms	remaining: 79.7ms
# 715:	learn: 0.0209284	total: 200ms	remaining: 79.4ms
# 716:	learn: 0.0209134	total: 200ms	remaining: 79.1ms
# 717:	learn: 0.0208334	total: 201ms	remaining: 78.8ms
# 718:	learn: 0.0208174	total: 201ms	remaining: 78.5ms
# 719:	learn: 0.0207635	total: 201ms	remaining: 78.2ms
# 720:	learn: 0.0207219	total: 201ms	remaining: 77.9ms
# 721:	learn: 0.0206815	total: 201ms	remaining: 77.6ms
# 722:	learn: 0.0206669	total: 202ms	remaining: 77.3ms
# 723:	learn: 0.0206292	total: 202ms	remaining: 77ms
# 724:	learn: 0.0206150	total: 202ms	remaining: 76.7ms
# 725:	learn: 0.0205994	total: 202ms	remaining: 76.4ms
# 726:	learn: 0.0205397	total: 203ms	remaining: 76.1ms
# 727:	learn: 0.0205052	total: 203ms	remaining: 75.8ms
# 728:	learn: 0.0204901	total: 203ms	remaining: 75.6ms
# 729:	learn: 0.0204761	total: 204ms	remaining: 75.3ms
# 730:	learn: 0.0204712	total: 204ms	remaining: 75ms
# 731:	learn: 0.0204125	total: 204ms	remaining: 74.7ms
# 732:	learn: 0.0203988	total: 204ms	remaining: 74.4ms
# 733:	learn: 0.0203422	total: 204ms	remaining: 74.1ms
# 734:	learn: 0.0203287	total: 205ms	remaining: 73.8ms
# 735:	learn: 0.0203239	total: 205ms	remaining: 73.5ms
# 736:	learn: 0.0202461	total: 205ms	remaining: 73.2ms
# 737:	learn: 0.0202161	total: 205ms	remaining: 72.9ms
# 738:	learn: 0.0201848	total: 206ms	remaining: 72.7ms
# 739:	learn: 0.0201705	total: 206ms	remaining: 72.4ms
# 740:	learn: 0.0201192	total: 206ms	remaining: 72.1ms
# 741:	learn: 0.0200429	total: 207ms	remaining: 71.8ms
# 742:	learn: 0.0200381	total: 207ms	remaining: 71.5ms
# 743:	learn: 0.0200334	total: 207ms	remaining: 71.2ms
# 744:	learn: 0.0199564	total: 207ms	remaining: 70.9ms
# 745:	learn: 0.0198818	total: 207ms	remaining: 70.6ms
# 746:	learn: 0.0198517	total: 208ms	remaining: 70.3ms
# 747:	learn: 0.0198386	total: 208ms	remaining: 70ms
# 748:	learn: 0.0198340	total: 208ms	remaining: 69.7ms
# 749:	learn: 0.0197606	total: 208ms	remaining: 69.4ms
# 750:	learn: 0.0197560	total: 209ms	remaining: 69.1ms
# 751:	learn: 0.0197269	total: 209ms	remaining: 68.8ms
# 752:	learn: 0.0196547	total: 209ms	remaining: 68.5ms
# 753:	learn: 0.0196250	total: 209ms	remaining: 68.3ms
# 754:	learn: 0.0196154	total: 209ms	remaining: 68ms
# 755:	learn: 0.0195875	total: 210ms	remaining: 67.7ms
# 756:	learn: 0.0195782	total: 210ms	remaining: 67.4ms
# 757:	learn: 0.0195737	total: 211ms	remaining: 67.2ms
# 758:	learn: 0.0195025	total: 211ms	remaining: 66.9ms
# 759:	learn: 0.0194539	total: 211ms	remaining: 66.6ms
# 760:	learn: 0.0194495	total: 211ms	remaining: 66.3ms
# 761:	learn: 0.0194169	total: 211ms	remaining: 66ms
# 762:	learn: 0.0194125	total: 212ms	remaining: 65.7ms
# 763:	learn: 0.0193428	total: 212ms	remaining: 65.5ms
# 764:	learn: 0.0193108	total: 212ms	remaining: 65.2ms
# 765:	learn: 0.0192314	total: 212ms	remaining: 64.9ms
# 766:	learn: 0.0192222	total: 213ms	remaining: 64.6ms
# 767:	learn: 0.0191936	total: 213ms	remaining: 64.3ms
# 768:	learn: 0.0191605	total: 213ms	remaining: 64ms
# 769:	learn: 0.0191485	total: 214ms	remaining: 63.9ms
# 770:	learn: 0.0191442	total: 214ms	remaining: 63.7ms
# 771:	learn: 0.0191134	total: 215ms	remaining: 63.4ms
# 772:	learn: 0.0191092	total: 215ms	remaining: 63.1ms
# 773:	learn: 0.0190789	total: 215ms	remaining: 62.8ms
# 774:	learn: 0.0190672	total: 215ms	remaining: 62.5ms
# 775:	learn: 0.0190630	total: 216ms	remaining: 62.2ms
# 776:	learn: 0.0190367	total: 216ms	remaining: 61.9ms
# 777:	learn: 0.0189571	total: 216ms	remaining: 61.6ms
# 778:	learn: 0.0188895	total: 219ms	remaining: 62.2ms
# 779:	learn: 0.0188619	total: 220ms	remaining: 61.9ms
# 780:	learn: 0.0188393	total: 220ms	remaining: 61.7ms
# 781:	learn: 0.0188209	total: 220ms	remaining: 61.4ms
# 782:	learn: 0.0188028	total: 220ms	remaining: 61.1ms
# 783:	learn: 0.0187987	total: 221ms	remaining: 60.8ms
# 784:	learn: 0.0187735	total: 221ms	remaining: 60.5ms
# 785:	learn: 0.0187694	total: 221ms	remaining: 60.2ms
# 786:	learn: 0.0187440	total: 221ms	remaining: 59.9ms
# 787:	learn: 0.0186725	total: 222ms	remaining: 59.6ms
# 788:	learn: 0.0186685	total: 222ms	remaining: 59.4ms
# 789:	learn: 0.0185907	total: 222ms	remaining: 59.1ms
# 790:	learn: 0.0185246	total: 222ms	remaining: 58.8ms
# 791:	learn: 0.0185035	total: 223ms	remaining: 58.5ms
# 792:	learn: 0.0184730	total: 223ms	remaining: 58.2ms
# 793:	learn: 0.0184602	total: 223ms	remaining: 57.9ms
# 794:	learn: 0.0183906	total: 224ms	remaining: 57.6ms
# 795:	learn: 0.0183866	total: 224ms	remaining: 57.4ms
# 796:	learn: 0.0183127	total: 224ms	remaining: 57.1ms
# 797:	learn: 0.0183030	total: 224ms	remaining: 56.8ms
# 798:	learn: 0.0182991	total: 225ms	remaining: 56.5ms
# 799:	learn: 0.0182952	total: 225ms	remaining: 56.2ms
# 800:	learn: 0.0182270	total: 225ms	remaining: 56ms
# 801:	learn: 0.0182026	total: 225ms	remaining: 55.7ms
# 802:	learn: 0.0181247	total: 226ms	remaining: 55.4ms
# 803:	learn: 0.0180578	total: 226ms	remaining: 55.1ms
# 804:	learn: 0.0179946	total: 226ms	remaining: 54.8ms
# 805:	learn: 0.0179907	total: 226ms	remaining: 54.5ms
# 806:	learn: 0.0179617	total: 227ms	remaining: 54.2ms
# 807:	learn: 0.0179293	total: 227ms	remaining: 54ms
# 808:	learn: 0.0179027	total: 228ms	remaining: 53.7ms
# 809:	learn: 0.0178933	total: 228ms	remaining: 53.4ms
# 810:	learn: 0.0178179	total: 228ms	remaining: 53.1ms
# 811:	learn: 0.0177978	total: 228ms	remaining: 52.9ms
# 812:	learn: 0.0177231	total: 229ms	remaining: 52.6ms
# 813:	learn: 0.0177111	total: 229ms	remaining: 52.3ms
# 814:	learn: 0.0176373	total: 229ms	remaining: 52ms
# 815:	learn: 0.0176335	total: 229ms	remaining: 51.7ms
# 816:	learn: 0.0176101	total: 230ms	remaining: 51.4ms
# 817:	learn: 0.0175372	total: 230ms	remaining: 51.1ms
# 818:	learn: 0.0174652	total: 230ms	remaining: 50.8ms
# 819:	learn: 0.0174614	total: 230ms	remaining: 50.6ms
# 820:	learn: 0.0174343	total: 231ms	remaining: 50.3ms
# 821:	learn: 0.0174057	total: 231ms	remaining: 50ms
# 822:	learn: 0.0174019	total: 231ms	remaining: 49.7ms
# 823:	learn: 0.0173737	total: 231ms	remaining: 49.4ms
# 824:	learn: 0.0173497	total: 232ms	remaining: 49.1ms
# 825:	learn: 0.0172787	total: 236ms	remaining: 49.6ms
# 826:	learn: 0.0172085	total: 236ms	remaining: 49.4ms
# 827:	learn: 0.0172048	total: 237ms	remaining: 49.1ms
# 828:	learn: 0.0171858	total: 237ms	remaining: 48.9ms
# 829:	learn: 0.0171613	total: 237ms	remaining: 48.6ms
# 830:	learn: 0.0171335	total: 238ms	remaining: 48.3ms
# 831:	learn: 0.0171097	total: 238ms	remaining: 48.1ms
# 832:	learn: 0.0170823	total: 238ms	remaining: 47.8ms
# 833:	learn: 0.0170553	total: 239ms	remaining: 47.5ms
# 834:	learn: 0.0170287	total: 239ms	remaining: 47.2ms
# 835:	learn: 0.0170056	total: 239ms	remaining: 47ms
# 836:	learn: 0.0169354	total: 240ms	remaining: 46.7ms
# 837:	learn: 0.0168672	total: 240ms	remaining: 46.4ms
# 838:	learn: 0.0168008	total: 240ms	remaining: 46.1ms
# 839:	learn: 0.0167682	total: 241ms	remaining: 45.8ms
# 840:	learn: 0.0167645	total: 241ms	remaining: 45.6ms
# 841:	learn: 0.0167609	total: 241ms	remaining: 45.3ms
# 842:	learn: 0.0167293	total: 242ms	remaining: 45ms
# 843:	learn: 0.0167257	total: 242ms	remaining: 44.7ms
# 844:	learn: 0.0166569	total: 242ms	remaining: 44.4ms
# 845:	learn: 0.0166534	total: 242ms	remaining: 44.1ms
# 846:	learn: 0.0165795	total: 243ms	remaining: 43.9ms
# 847:	learn: 0.0165760	total: 243ms	remaining: 43.6ms
# 848:	learn: 0.0165726	total: 243ms	remaining: 43.3ms
# 849:	learn: 0.0165082	total: 244ms	remaining: 43ms
# 850:	learn: 0.0164775	total: 244ms	remaining: 42.7ms
# 851:	learn: 0.0164101	total: 244ms	remaining: 42.4ms
# 852:	learn: 0.0164067	total: 245ms	remaining: 42.2ms
# 853:	learn: 0.0163401	total: 245ms	remaining: 41.9ms
# 854:	learn: 0.0163368	total: 245ms	remaining: 41.6ms
# 855:	learn: 0.0162691	total: 246ms	remaining: 41.3ms
# 856:	learn: 0.0162657	total: 246ms	remaining: 41ms
# 857:	learn: 0.0162034	total: 246ms	remaining: 40.8ms
# 858:	learn: 0.0162000	total: 247ms	remaining: 40.5ms
# 859:	learn: 0.0161393	total: 247ms	remaining: 40.2ms
# 860:	learn: 0.0161211	total: 247ms	remaining: 39.9ms
# 861:	learn: 0.0160437	total: 248ms	remaining: 39.6ms
# 862:	learn: 0.0159791	total: 248ms	remaining: 39.4ms
# 863:	learn: 0.0159154	total: 248ms	remaining: 39.1ms
# 864:	learn: 0.0158976	total: 248ms	remaining: 38.8ms
# 865:	learn: 0.0158345	total: 249ms	remaining: 38.5ms
# 866:	learn: 0.0157723	total: 249ms	remaining: 38.2ms
# 867:	learn: 0.0157427	total: 249ms	remaining: 37.9ms
# 868:	learn: 0.0156811	total: 250ms	remaining: 37.6ms
# 869:	learn: 0.0156273	total: 250ms	remaining: 37.3ms
# 870:	learn: 0.0155666	total: 250ms	remaining: 37ms
# 871:	learn: 0.0155633	total: 251ms	remaining: 36.8ms
# 872:	learn: 0.0155033	total: 251ms	remaining: 36.6ms
# 873:	learn: 0.0154513	total: 252ms	remaining: 36.3ms
# 874:	learn: 0.0154480	total: 252ms	remaining: 36ms
# 875:	learn: 0.0153855	total: 252ms	remaining: 35.7ms
# 876:	learn: 0.0153822	total: 253ms	remaining: 35.4ms
# 877:	learn: 0.0153235	total: 253ms	remaining: 35.2ms
# 878:	learn: 0.0153203	total: 253ms	remaining: 34.9ms
# 879:	learn: 0.0152980	total: 254ms	remaining: 34.6ms
# 880:	learn: 0.0152479	total: 254ms	remaining: 34.4ms
# 881:	learn: 0.0152447	total: 255ms	remaining: 34.1ms
# 882:	learn: 0.0151927	total: 255ms	remaining: 33.8ms
# 883:	learn: 0.0151708	total: 255ms	remaining: 33.5ms
# 884:	learn: 0.0151676	total: 256ms	remaining: 33.2ms
# 885:	learn: 0.0151504	total: 256ms	remaining: 32.9ms
# 886:	learn: 0.0150988	total: 256ms	remaining: 32.6ms
# 887:	learn: 0.0150957	total: 256ms	remaining: 32.3ms
# 888:	learn: 0.0150788	total: 257ms	remaining: 32ms
# 889:	learn: 0.0150277	total: 257ms	remaining: 31.8ms
# 890:	learn: 0.0149772	total: 257ms	remaining: 31.5ms
# 891:	learn: 0.0149741	total: 257ms	remaining: 31.2ms
# 892:	learn: 0.0149525	total: 258ms	remaining: 30.9ms
# 893:	learn: 0.0149250	total: 258ms	remaining: 30.6ms
# 894:	learn: 0.0148880	total: 258ms	remaining: 30.3ms
# 895:	learn: 0.0148849	total: 258ms	remaining: 30ms
# 896:	learn: 0.0148819	total: 259ms	remaining: 29.7ms
# 897:	learn: 0.0148789	total: 259ms	remaining: 29.4ms
# 898:	learn: 0.0148224	total: 259ms	remaining: 29.1ms
# 899:	learn: 0.0148048	total: 259ms	remaining: 28.8ms
# 900:	learn: 0.0147489	total: 260ms	remaining: 28.5ms
# 901:	learn: 0.0146977	total: 260ms	remaining: 28.2ms
# 902:	learn: 0.0146619	total: 260ms	remaining: 28ms
# 903:	learn: 0.0146589	total: 260ms	remaining: 27.7ms
# 904:	learn: 0.0146561	total: 261ms	remaining: 27.4ms
# 905:	learn: 0.0146400	total: 261ms	remaining: 27.1ms
# 906:	learn: 0.0145906	total: 261ms	remaining: 26.8ms
# 907:	learn: 0.0145417	total: 261ms	remaining: 26.5ms
# 908:	learn: 0.0145388	total: 262ms	remaining: 26.2ms
# 909:	learn: 0.0145167	total: 262ms	remaining: 25.9ms
# 910:	learn: 0.0145023	total: 262ms	remaining: 25.6ms
# 911:	learn: 0.0144539	total: 262ms	remaining: 25.3ms
# 912:	learn: 0.0144379	total: 263ms	remaining: 25ms
# 913:	learn: 0.0143838	total: 263ms	remaining: 24.7ms
# 914:	learn: 0.0143647	total: 263ms	remaining: 24.5ms
# 915:	learn: 0.0143172	total: 264ms	remaining: 24.2ms
# 916:	learn: 0.0142641	total: 264ms	remaining: 23.9ms
# 917:	learn: 0.0142331	total: 264ms	remaining: 23.6ms
# 918:	learn: 0.0142172	total: 264ms	remaining: 23.3ms
# 919:	learn: 0.0142033	total: 265ms	remaining: 23ms
# 920:	learn: 0.0141567	total: 265ms	remaining: 22.7ms
# 921:	learn: 0.0141265	total: 265ms	remaining: 22.4ms
# 922:	learn: 0.0141058	total: 265ms	remaining: 22.1ms
# 923:	learn: 0.0140855	total: 266ms	remaining: 21.8ms
# 924:	learn: 0.0140740	total: 266ms	remaining: 21.6ms
# 925:	learn: 0.0140587	total: 266ms	remaining: 21.3ms
# 926:	learn: 0.0140388	total: 266ms	remaining: 21ms
# 927:	learn: 0.0140010	total: 267ms	remaining: 20.7ms
# 928:	learn: 0.0139713	total: 267ms	remaining: 20.4ms
# 929:	learn: 0.0139565	total: 267ms	remaining: 20.1ms
# 930:	learn: 0.0139419	total: 267ms	remaining: 19.8ms
# 931:	learn: 0.0139308	total: 268ms	remaining: 19.5ms
# 932:	learn: 0.0139164	total: 268ms	remaining: 19.2ms
# 933:	learn: 0.0138974	total: 268ms	remaining: 18.9ms
# 934:	learn: 0.0138866	total: 268ms	remaining: 18.7ms
# 935:	learn: 0.0138725	total: 269ms	remaining: 18.4ms
# 936:	learn: 0.0138472	total: 269ms	remaining: 18.1ms
# 937:	learn: 0.0138366	total: 269ms	remaining: 17.8ms
# 938:	learn: 0.0138172	total: 269ms	remaining: 17.5ms
# 939:	learn: 0.0138068	total: 270ms	remaining: 17.2ms
# 940:	learn: 0.0137609	total: 270ms	remaining: 16.9ms
# 941:	learn: 0.0137428	total: 270ms	remaining: 16.6ms
# 942:	learn: 0.0136826	total: 271ms	remaining: 16.4ms
# 943:	learn: 0.0136379	total: 271ms	remaining: 16.1ms
# 944:	learn: 0.0136278	total: 271ms	remaining: 15.8ms
# 945:	learn: 0.0136101	total: 271ms	remaining: 15.5ms
# 946:	learn: 0.0135651	total: 271ms	remaining: 15.2ms
# 947:	learn: 0.0135518	total: 272ms	remaining: 14.9ms
# 948:	learn: 0.0135183	total: 272ms	remaining: 14.6ms
# 949:	learn: 0.0135026	total: 272ms	remaining: 14.3ms
# 950:	learn: 0.0134673	total: 272ms	remaining: 14ms
# 951:	learn: 0.0134518	total: 273ms	remaining: 13.7ms
# 952:	learn: 0.0133933	total: 273ms	remaining: 13.5ms
# 953:	learn: 0.0133803	total: 273ms	remaining: 13.2ms
# 954:	learn: 0.0133652	total: 273ms	remaining: 12.9ms
# 955:	learn: 0.0133076	total: 274ms	remaining: 12.6ms
# 956:	learn: 0.0132508	total: 274ms	remaining: 12.3ms
# 957:	learn: 0.0132378	total: 274ms	remaining: 12ms
# 958:	learn: 0.0132233	total: 274ms	remaining: 11.7ms
# 959:	learn: 0.0131674	total: 274ms	remaining: 11.4ms
# 960:	learn: 0.0131594	total: 275ms	remaining: 11.1ms
# 961:	learn: 0.0131042	total: 275ms	remaining: 10.9ms
# 962:	learn: 0.0130913	total: 275ms	remaining: 10.6ms
# 963:	learn: 0.0130574	total: 275ms	remaining: 10.3ms
# 964:	learn: 0.0130433	total: 276ms	remaining: 9.99ms
# 965:	learn: 0.0130354	total: 276ms	remaining: 9.7ms
# 966:	learn: 0.0130217	total: 276ms	remaining: 9.42ms
# 967:	learn: 0.0129765	total: 276ms	remaining: 9.13ms
# 968:	learn: 0.0129687	total: 276ms	remaining: 8.84ms
# 969:	learn: 0.0129149	total: 277ms	remaining: 8.55ms
# 970:	learn: 0.0129016	total: 277ms	remaining: 8.27ms
# 971:	learn: 0.0128939	total: 277ms	remaining: 7.98ms
# 972:	learn: 0.0128498	total: 277ms	remaining: 7.69ms
# 973:	learn: 0.0128422	total: 277ms	remaining: 7.41ms
# 974:	learn: 0.0128140	total: 278ms	remaining: 7.12ms
# 975:	learn: 0.0127811	total: 278ms	remaining: 6.84ms
# 976:	learn: 0.0127411	total: 278ms	remaining: 6.55ms
# 977:	learn: 0.0127281	total: 278ms	remaining: 6.26ms
# 978:	learn: 0.0127140	total: 279ms	remaining: 5.98ms
# 979:	learn: 0.0126963	total: 279ms	remaining: 5.69ms
# 980:	learn: 0.0126837	total: 279ms	remaining: 5.41ms
# 981:	learn: 0.0126406	total: 279ms	remaining: 5.12ms
# 982:	learn: 0.0126331	total: 280ms	remaining: 4.83ms
# 983:	learn: 0.0125814	total: 280ms	remaining: 4.55ms
# 984:	learn: 0.0125640	total: 280ms	remaining: 4.26ms
# 985:	learn: 0.0125323	total: 280ms	remaining: 3.98ms
# 986:	learn: 0.0125200	total: 280ms	remaining: 3.69ms
# 987:	learn: 0.0125059	total: 281ms	remaining: 3.41ms
# 988:	learn: 0.0124637	total: 281ms	remaining: 3.12ms
# 989:	learn: 0.0124131	total: 281ms	remaining: 2.84ms
# 990:	learn: 0.0123840	total: 281ms	remaining: 2.56ms
# 991:	learn: 0.0123461	total: 282ms	remaining: 2.27ms
# 992:	learn: 0.0123344	total: 282ms	remaining: 1.99ms
# 993:	learn: 0.0123174	total: 282ms	remaining: 1.7ms
# 994:	learn: 0.0123006	total: 282ms	remaining: 1.42ms
# 995:	learn: 0.0122891	total: 283ms	remaining: 1.13ms
# 996:	learn: 0.0122484	total: 283ms	remaining: 850us
# 997:	learn: 0.0122081	total: 283ms	remaining: 566us
# 998:	learn: 0.0121917	total: 283ms	remaining: 283us
# 999:	learn: 0.0121618	total: 283ms	remaining: 0us
# Training Accuracy: 92.10 %
# Training data Standard Deviation: 4.99 %
# r_2_score =  0.984711472610612
# MSE =  0.10376710670639222
# RMSE =  0.01076761243421579
# Compare with Predict and actual
#  [[1.   1.16]
#  [0.   0.17]
#  [2.   1.82]
#  [1.   1.11]
#  [1.   1.06]
#  [0.   0.12]
#  [1.   0.96]
#  [2.   1.87]
#  [1.   1.29]
#  [1.   1.02]]
